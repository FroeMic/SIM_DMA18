# %%
import pandas as pd # package for high-performance, easy-to-use data structures and data analysis
import numpy as np # fundamental package for scientific computing with Python

# %%
from subprocess import check_output
print(check_output(["ls", "./export/census_tracts_lookup"]).decode("utf8"))
# Out:
# Alabama.csv
# Alaska.csv
# Arizona.csv
# Arkansas.csv
# California.csv
# Colorado.csv
# Connecticut.csv
# Delaware.csv
# District of Columbia.csv
# Florida.csv
# Georgia.csv
# Hawaii.csv
# Idaho.csv
# Illinois.csv
# Indiana.csv
# Iowa.csv
# Kansas.csv
# Kentucky.csv
# Louisiana.csv
# Maine.csv
# Maryland.csv
# Massachusetts.csv
# Michigan.csv
# Minnesota.csv
# Mississippi.csv
# Missouri.csv
# Montana.csv
# Nebraska.csv
# Nevada.csv
# New Hampshire.csv
# New Jersey.csv
# New Mexico.csv
# New York.csv
# North Carolina.csv
# North Dakota.csv
# Ohio.csv
# Oklahoma.csv
# Oregon.csv
# Pennsylvania.csv
# Rhode Island.csv
# South Carolina.csv
# South Dakota.csv
# Tennessee.csv
# Texas.csv
# Utah.csv
# Vermont.csv
# Virginia.csv
# Washington.csv
# West Virginia.csv
# Wisconsin.csv
# Wyoming.csv
# all_states.csv
# faulty_census_tracts.csv

# %%
census_lookup = pd.read_csv("./export/census_tracts_lookup/California.csv", delimiter=",")

# %%
census_lookup.head()
# Out:
#    state_code       state  county_code          county  census_tracts  \
# 0           6  California            1  Alameda County           3076
# 1           6  California            1  Alameda County            230
# 2           6  California            1  Alameda County            341
# 3           6  California            1  Alameda County           1107
# 4           6  California            1  Alameda County           2607
#
#    census_tract_number
# 0              4301.01
# 1              4229.00
# 2              4041.02
# 3              4371.02
# 4              4273.00

# %%
import os

def make_sure_directory_exists(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
def export(path, filename, df, append=False):
    make_sure_directory_exists(path)
    filepath = os.path.join(path, filename)

    if not append:
        df.to_csv(filepath ,index=False, sep=',')
    else:
        df.to_csv(filepath, mode = 'a',index=False, sep=',')
   
''' These are the HDMA dataset columns'''
COLUMNS = [
    'action_taken',
    'action_taken_name',
    'agency_abbr',
    'agency_code',
    'agency_name',
    'applicant_ethnicity',
    'applicant_ethnicity_name',
    'applicant_income_000s',
    'applicant_race_1',
    'applicant_race_2',
    'applicant_race_3',
    'applicant_race_4',
    'applicant_race_5',
    'applicant_race_name_1',
    'applicant_race_name_2',
    'applicant_race_name_3',
    'applicant_race_name_4',
    'applicant_race_name_5',
    'applicant_sex',
    'applicant_sex_name',
    'application_date_indicator',
    'as_of_year',
    'census_tract_number',
    'co_applicant_ethnicity',
    'co_applicant_ethnicity_name',
    'co_applicant_race_1',
    'co_applicant_race_2',
    'co_applicant_race_3',
    'co_applicant_race_4',
    'co_applicant_race_5',
    'co_applicant_race_name_1',
    'co_applicant_race_name_2',
    'co_applicant_race_name_3',
    'co_applicant_race_name_4',
    'co_applicant_race_name_5',
    'co_applicant_sex',
    'co_applicant_sex_name',
    'county_code',
    'county_name',
    'denial_reason_1',
    'denial_reason_2',
    'denial_reason_3',
    'denial_reason_name_1',
    'denial_reason_name_2',
    'denial_reason_name_3',
    'edit_status',
    'edit_status_name',
    'hoepa_status',
    'hoepa_status_name',
    'hud_median_family_income',
    'lien_status',
    'lien_status_name',
    'loan_amount_000s',
    'loan_purpose',
    'loan_purpose_name',
    'loan_type',
    'loan_type_name',
    'minority_population',
    'msamd',
    'msamd_name',
    'number_of_1_to_4_family_units',
    'number_of_owner_occupied_units',
    'owner_occupancy',
    'owner_occupancy_name',
    'population',
    'preapproval',
    'preapproval_name',
    'property_type',
    'property_type_name',
    'purchaser_type',
    'purchaser_type_name',
    'rate_spread',
    'respondent_id',
    'sequence_number',
    'state_abbr',
    'state_code',
    'state_name',
    'tract_to_msamd_income'
]

# %%
''' Queries the HDMA API for the census tracts specified in the census_lookup dataframe.'''
import requests

verbose = True
page_size = 250000
path = './export/hmda_data'

is_first_census = True
count = 0
for row in census_lookup.iterrows():
    count += 1
    state_code = row[1][0]
    state_name = row[1][1]
    county_code = '{:03d}'.format(int(row[1][2]))
    county_name = row[1][3]
    census_tracts= row[1][4]
    census_tract_number = row[1][5]
    
    results = []
    offset = 0
    url_template = 'https://api.consumerfinance.gov:443/data/hmda/slice/hmda_lar.json?$where=state_code={}+AND+county_code={}+AND+census_tract_number="{}"&$limit={}&$offset={}'
    while True:
        url = url_template.format(state_code, county_code, census_tract_number, page_size, offset)
        response = requests.get(url).json()
        if response is None or response.get('results') is None:
            continue
        for loan in response['results']:
            results.append([loan.get(column) for column in COLUMNS])
            
        if len(results) < int(response['total']):
            offset += page_size
        else:
            break
            
    # export after every census
    filename = '2016_{}_HDMA.csv'.format(state_name)
    filepath = os.path.join(path, filename)
    verbose and print("{:05d} :: saving {} to '{}'".format(count,census_tract_number, filepath))
    state_df = pd.DataFrame(results, dtype=str, columns = COLUMNS)
    export(path, filename, state_df, append=not is_first_census)        
    is_first_census = False
    
print('Finished')
# Out:
# 00001 :: saving 4301.01 to './data/2016_California_HDMA.csv'
# 00002 :: saving 4229.0 to './data/2016_California_HDMA.csv'
# 00003 :: saving 4041.02 to './data/2016_California_HDMA.csv'
# 00004 :: saving 4371.02 to './data/2016_California_HDMA.csv'
# 00005 :: saving 4273.0 to './data/2016_California_HDMA.csv'
# 00006 :: saving 4283.01 to './data/2016_California_HDMA.csv'
# 00007 :: saving 4331.04 to './data/2016_California_HDMA.csv'
# 00008 :: saving 4285.0 to './data/2016_California_HDMA.csv'
# 00009 :: saving 4003.0 to './data/2016_California_HDMA.csv'
# 00010 :: saving 4362.0 to './data/2016_California_HDMA.csv'
# 00011 :: saving 4443.02 to './data/2016_California_HDMA.csv'
# 00012 :: saving 4321.0 to './data/2016_California_HDMA.csv'
# 00013 :: saving 4012.0 to './data/2016_California_HDMA.csv'
# 00014 :: saving 4058.0 to './data/2016_California_HDMA.csv'
# 00015 :: saving 4423.02 to './data/2016_California_HDMA.csv'
# 00016 :: saving 4070.0 to './data/2016_California_HDMA.csv'
# 00017 :: saving 4224.0 to './data/2016_California_HDMA.csv'
# 00018 :: saving 4096.0 to './data/2016_California_HDMA.csv'
# 00019 :: saving 4359.0 to './data/2016_California_HDMA.csv'
# 00020 :: saving 4275.0 to './data/2016_California_HDMA.csv'
# 00021 :: saving 4506.05 to './data/2016_California_HDMA.csv'
# 00022 :: saving 4045.02 to './data/2016_California_HDMA.csv'
# 00023 :: saving 4068.0 to './data/2016_California_HDMA.csv'
# 00024 :: saving 4506.02 to './data/2016_California_HDMA.csv'
# 00025 :: saving 4403.05 to './data/2016_California_HDMA.csv'
# 00026 :: saving 9832.0 to './data/2016_California_HDMA.csv'
# 00027 :: saving 4351.03 to './data/2016_California_HDMA.csv'
# 00028 :: saving 4306.0 to './data/2016_California_HDMA.csv'
# 00029 :: saving 4328.0 to './data/2016_California_HDMA.csv'
# 00030 :: saving 4240.01 to './data/2016_California_HDMA.csv'
# 00031 :: saving 4382.02 to './data/2016_California_HDMA.csv'
# 00032 :: saving 4432.0 to './data/2016_California_HDMA.csv'
# 00033 :: saving 4430.02 to './data/2016_California_HDMA.csv'
# 00034 :: saving 4099.0 to './data/2016_California_HDMA.csv'
# 00035 :: saving 4403.32 to './data/2016_California_HDMA.csv'
# 00036 :: saving 4071.01 to './data/2016_California_HDMA.csv'
# 00037 :: saving 4228.0 to './data/2016_California_HDMA.csv'
# 00038 :: saving 4431.03 to './data/2016_California_HDMA.csv'
# 00039 :: saving 4325.02 to './data/2016_California_HDMA.csv'
# 00040 :: saving 4507.46 to './data/2016_California_HDMA.csv'
# 00041 :: saving 4514.01 to './data/2016_California_HDMA.csv'
# 00042 :: saving 4071.0 to './data/2016_California_HDMA.csv'
# 00043 :: saving 4369.0 to './data/2016_California_HDMA.csv'
# 00044 :: saving 4004.0 to './data/2016_California_HDMA.csv'
# 00045 :: saving 4442.0 to './data/2016_California_HDMA.csv'
# 00046 :: saving 4423.01 to './data/2016_California_HDMA.csv'
# 00047 :: saving 4444.0 to './data/2016_California_HDMA.csv'
# 00048 :: saving 4304.0 to './data/2016_California_HDMA.csv'
# 00049 :: saving 4013.0 to './data/2016_California_HDMA.csv'
# 00050 :: saving 4038.0 to './data/2016_California_HDMA.csv'
# 00051 :: saving 4009.0 to './data/2016_California_HDMA.csv'
# 00052 :: saving 4507.43 to './data/2016_California_HDMA.csv'
# 00053 :: saving 4339.0 to './data/2016_California_HDMA.csv'
# 00054 :: saving 4026.0 to './data/2016_California_HDMA.csv'
# 00055 :: saving 4413.01 to './data/2016_California_HDMA.csv'
# 00056 :: saving 4240.01 to './data/2016_California_HDMA.csv'
# 00057 :: saving 4280.0 to './data/2016_California_HDMA.csv'
# 00058 :: saving 4415.24 to './data/2016_California_HDMA.csv'
# 00059 :: saving 4310.0 to './data/2016_California_HDMA.csv'
# 00060 :: saving 4515.05 to './data/2016_California_HDMA.csv'
# 00061 :: saving 4055.0 to './data/2016_California_HDMA.csv'
# 00062 :: saving 4301.0 to './data/2016_California_HDMA.csv'
# 00063 :: saving 4071.02 to './data/2016_California_HDMA.csv'
# 00064 :: saving 4402.0 to './data/2016_California_HDMA.csv'
# 00065 :: saving 4364.01 to './data/2016_California_HDMA.csv'
# 00066 :: saving 4223.0 to './data/2016_California_HDMA.csv'
# 00067 :: saving 4446.02 to './data/2016_California_HDMA.csv'
# 00068 :: saving 4014.0 to './data/2016_California_HDMA.csv'
# 00069 :: saving 4235.0 to './data/2016_California_HDMA.csv'
# 00070 :: saving 4375.0 to './data/2016_California_HDMA.csv'
# 00071 :: saving 4091.0 to './data/2016_California_HDMA.csv'
# 00072 :: saving 4377.02 to './data/2016_California_HDMA.csv'
# 00073 :: saving 4330.0 to './data/2016_California_HDMA.csv'
# 00074 :: saving 4061.0 to './data/2016_California_HDMA.csv'
# 00075 :: saving 4368.0 to './data/2016_California_HDMA.csv'
# 00076 :: saving 4079.0 to './data/2016_California_HDMA.csv'
# 00077 :: saving 4048.0 to './data/2016_California_HDMA.csv'
# 00078 :: saving 4312.0 to './data/2016_California_HDMA.csv'
# 00079 :: saving 4326.0 to './data/2016_California_HDMA.csv'
# 00080 :: saving 4501.02 to './data/2016_California_HDMA.csv'
# 00081 :: saving 4088.0 to './data/2016_California_HDMA.csv'
# 00082 :: saving 4282.0 to './data/2016_California_HDMA.csv'
# 00083 :: saving nan to './data/2016_California_HDMA.csv'
# 00084 :: saving 4010.0 to './data/2016_California_HDMA.csv'
# 00085 :: saving 4512.01 to './data/2016_California_HDMA.csv'
# 00086 :: saving 4080.0 to './data/2016_California_HDMA.csv'
# 00087 :: saving 4205.0 to './data/2016_California_HDMA.csv'
# 00088 :: saving 4403.01 to './data/2016_California_HDMA.csv'
# 00089 :: saving 4356.0 to './data/2016_California_HDMA.csv'
# 00090 :: saving 4006.0 to './data/2016_California_HDMA.csv'
# 00091 :: saving 4419.27 to './data/2016_California_HDMA.csv'
# 00092 :: saving 4037.02 to './data/2016_California_HDMA.csv'
# 00093 :: saving 4433.22 to './data/2016_California_HDMA.csv'
# 00094 :: saving 4271.0 to './data/2016_California_HDMA.csv'
# 00095 :: saving 4331.01 to './data/2016_California_HDMA.csv'
# 00096 :: saving 4011.0 to './data/2016_California_HDMA.csv'
# 00097 :: saving 4082.0 to './data/2016_California_HDMA.csv'
# 00098 :: saving 4380.0 to './data/2016_California_HDMA.csv'
# 00099 :: saving 4431.04 to './data/2016_California_HDMA.csv'
# 00100 :: saving 4035.01 to './data/2016_California_HDMA.csv'
# 00101 :: saving 4034.0 to './data/2016_California_HDMA.csv'
# 00102 :: saving 4251.02 to './data/2016_California_HDMA.csv'
# 00103 :: saving 4331.03 to './data/2016_California_HDMA.csv'
# 00104 :: saving 4517.04 to './data/2016_California_HDMA.csv'
# 00105 :: saving 4103.0 to './data/2016_California_HDMA.csv'
# 00106 :: saving 4031.0 to './data/2016_California_HDMA.csv'
# 00107 :: saving 4027.0 to './data/2016_California_HDMA.csv'
# 00108 :: saving 4015.0 to './data/2016_California_HDMA.csv'
# 00109 :: saving 4238.0 to './data/2016_California_HDMA.csv'
# 00110 :: saving 4515.04 to './data/2016_California_HDMA.csv'
# 00111 :: saving 4403.02 to './data/2016_California_HDMA.csv'
# 00112 :: saving 4507.5 to './data/2016_California_HDMA.csv'
# 00113 :: saving 4517.03 to './data/2016_California_HDMA.csv'
# 00114 :: saving 4429.0 to './data/2016_California_HDMA.csv'
# 00115 :: saving 4028.0 to './data/2016_California_HDMA.csv'
# 00116 :: saving 4361.0 to './data/2016_California_HDMA.csv'
# 00117 :: saving 4301.02 to './data/2016_California_HDMA.csv'
# 00118 :: saving 4021.0 to './data/2016_California_HDMA.csv'
# 00119 :: saving 4019.0 to './data/2016_California_HDMA.csv'
# 00120 :: saving 4042.0 to './data/2016_California_HDMA.csv'
# 00121 :: saving 4356.01 to './data/2016_California_HDMA.csv'
# 00122 :: saving 4039.0 to './data/2016_California_HDMA.csv'
# 00123 :: saving 4054.02 to './data/2016_California_HDMA.csv'
# 00124 :: saving 4403.35 to './data/2016_California_HDMA.csv'
# 00125 :: saving 4037.01 to './data/2016_California_HDMA.csv'
# 00126 :: saving 4382.03 to './data/2016_California_HDMA.csv'
# 00127 :: saving 4503.0 to './data/2016_California_HDMA.csv'
# 00128 :: saving 4325.01 to './data/2016_California_HDMA.csv'
# 00129 :: saving 4516.01 to './data/2016_California_HDMA.csv'
# 00130 :: saving 4043.0 to './data/2016_California_HDMA.csv'
# 00131 :: saving 4364.02 to './data/2016_California_HDMA.csv'
# 00132 :: saving 4428.0 to './data/2016_California_HDMA.csv'
# 00133 :: saving 4515.06 to './data/2016_California_HDMA.csv'
# 00134 :: saving 4373.0 to './data/2016_California_HDMA.csv'
# 00135 :: saving 4403.36 to './data/2016_California_HDMA.csv'
# 00136 :: saving 4419.21 to './data/2016_California_HDMA.csv'
# 00137 :: saving 4049.0 to './data/2016_California_HDMA.csv'
# 00138 :: saving 4045.01 to './data/2016_California_HDMA.csv'
# 00139 :: saving 4421.0 to './data/2016_California_HDMA.csv'
# 00140 :: saving 4365.0 to './data/2016_California_HDMA.csv'
# 00141 :: saving 4511.01 to './data/2016_California_HDMA.csv'
# 00142 :: saving 4424.0 to './data/2016_California_HDMA.csv'
# 00143 :: saving 9820.0 to './data/2016_California_HDMA.csv'
# 00144 :: saving 4415.22 to './data/2016_California_HDMA.csv'
# 00145 :: saving 4053.02 to './data/2016_California_HDMA.csv'
# 00146 :: saving 4311.0 to './data/2016_California_HDMA.csv'
# 00147 :: saving 4379.0 to './data/2016_California_HDMA.csv'
# 00148 :: saving 4506.01 to './data/2016_California_HDMA.csv'
# 00149 :: saving 4261.0 to './data/2016_California_HDMA.csv'
# 00150 :: saving 4414.01 to './data/2016_California_HDMA.csv'
# 00151 :: saving 4056.0 to './data/2016_California_HDMA.csv'
# 00152 :: saving 4066.0 to './data/2016_California_HDMA.csv'
# 00153 :: saving 4063.0 to './data/2016_California_HDMA.csv'
# 00154 :: saving 4075.0 to './data/2016_California_HDMA.csv'
# 00155 :: saving 4514.04 to './data/2016_California_HDMA.csv'
# 00156 :: saving 4277.0 to './data/2016_California_HDMA.csv'
# 00157 :: saving 4022.0 to './data/2016_California_HDMA.csv'
# 00158 :: saving 4239.02 to './data/2016_California_HDMA.csv'
# 00159 :: saving 4251.03 to './data/2016_California_HDMA.csv'
# 00160 :: saving 4415.23 to './data/2016_California_HDMA.csv'
# 00161 :: saving 4514.02 to './data/2016_California_HDMA.csv'
# 00162 :: saving 4415.03 to './data/2016_California_HDMA.csv'
# 00163 :: saving 4001.0 to './data/2016_California_HDMA.csv'
# 00164 :: saving 4287.0 to './data/2016_California_HDMA.csv'
# 00165 :: saving 4371.0 to './data/2016_California_HDMA.csv'
# 00166 :: saving 4506.04 to './data/2016_California_HDMA.csv'
# 00167 :: saving 4513.0 to './data/2016_California_HDMA.csv'
# 00168 :: saving 4016.0 to './data/2016_California_HDMA.csv'
# 00169 :: saving 4370.0 to './data/2016_California_HDMA.csv'
# 00170 :: saving 4515.03 to './data/2016_California_HDMA.csv'
# 00171 :: saving 4105.0 to './data/2016_California_HDMA.csv'
# 00172 :: saving 4431.02 to './data/2016_California_HDMA.csv'
# 00173 :: saving 4017.0 to './data/2016_California_HDMA.csv'
# 00174 :: saving 4352.0 to './data/2016_California_HDMA.csv'
# 00175 :: saving 4030.0 to './data/2016_California_HDMA.csv'
# 00176 :: saving 4505.0 to './data/2016_California_HDMA.csv'
# 00177 :: saving 4504.0 to './data/2016_California_HDMA.csv'
# 00178 :: saving 4024.0 to './data/2016_California_HDMA.csv'
# 00179 :: saving 4403.04 to './data/2016_California_HDMA.csv'
# 00180 :: saving 4423.0 to './data/2016_California_HDMA.csv'
# 00181 :: saving 4226.0 to './data/2016_California_HDMA.csv'
# 00182 :: saving 4276.0 to './data/2016_California_HDMA.csv'
# 00183 :: saving 4035.0 to './data/2016_California_HDMA.csv'
# 00184 :: saving 4501.01 to './data/2016_California_HDMA.csv'
# 00185 :: saving 4443.0 to './data/2016_California_HDMA.csv'
# 00186 :: saving 4204.0 to './data/2016_California_HDMA.csv'
# 00187 :: saving 4093.0 to './data/2016_California_HDMA.csv'
# 00188 :: saving 4281.0 to './data/2016_California_HDMA.csv'
# 00189 :: saving 4220.0 to './data/2016_California_HDMA.csv'
# 00190 :: saving 4072.0 to './data/2016_California_HDMA.csv'
# 00191 :: saving 4335.0 to './data/2016_California_HDMA.csv'
# 00192 :: saving 4502.0 to './data/2016_California_HDMA.csv'
# 00193 :: saving 4272.0 to './data/2016_California_HDMA.csv'
# 00194 :: saving 4507.51 to './data/2016_California_HDMA.csv'
# 00195 :: saving 4307.0 to './data/2016_California_HDMA.csv'
# 00196 :: saving 4053.0 to './data/2016_California_HDMA.csv'
# 00197 :: saving 4064.0 to './data/2016_California_HDMA.csv'
# 00198 :: saving 4403.07 to './data/2016_California_HDMA.csv'
# 00199 :: saving 4420.0 to './data/2016_California_HDMA.csv'
# 00200 :: saving 4419.26 to './data/2016_California_HDMA.csv'
# 00201 :: saving 4377.0 to './data/2016_California_HDMA.csv'
# 00202 :: saving 4501.0 to './data/2016_California_HDMA.csv'
# 00203 :: saving 4211.0 to './data/2016_California_HDMA.csv'
# 00204 :: saving 4076.0 to './data/2016_California_HDMA.csv'
# 00205 :: saving 4507.03 to './data/2016_California_HDMA.csv'
# 00206 :: saving 4237.0 to './data/2016_California_HDMA.csv'
# 00207 :: saving 4419.01 to './data/2016_California_HDMA.csv'
# 00208 :: saving 4309.0 to './data/2016_California_HDMA.csv'
# 00209 :: saving 4217.0 to './data/2016_California_HDMA.csv'
# 00210 :: saving 4222.0 to './data/2016_California_HDMA.csv'
# 00211 :: saving 4427.0 to './data/2016_California_HDMA.csv'
# 00212 :: saving 4059.01 to './data/2016_California_HDMA.csv'
# 00213 :: saving 4403.31 to './data/2016_California_HDMA.csv'
# 00214 :: saving 4419.22 to './data/2016_California_HDMA.csv'
# 00215 :: saving 4240.02 to './data/2016_California_HDMA.csv'
# 00216 :: saving 4092.0 to './data/2016_California_HDMA.csv'
# 00217 :: saving 4077.0 to './data/2016_California_HDMA.csv'
# 00218 :: saving 4403.08 to './data/2016_California_HDMA.csv'
# 00219 :: saving 4005.0 to './data/2016_California_HDMA.csv'
# 00220 :: saving 4213.0 to './data/2016_California_HDMA.csv'
# 00221 :: saving 4037.0 to './data/2016_California_HDMA.csv'
# 00222 :: saving 4401.0 to './data/2016_California_HDMA.csv'
# 00223 :: saving 4334.0 to './data/2016_California_HDMA.csv'
# 00224 :: saving 4098.0 to './data/2016_California_HDMA.csv'
# 00225 :: saving 4065.0 to './data/2016_California_HDMA.csv'
# 00226 :: saving 4351.01 to './data/2016_California_HDMA.csv'
# 00227 :: saving 4081.0 to './data/2016_California_HDMA.csv'
# 00228 :: saving 4104.0 to './data/2016_California_HDMA.csv'
# 00229 :: saving 4419.23 to './data/2016_California_HDMA.csv'
# 00230 :: saving 4085.0 to './data/2016_California_HDMA.csv'
# 00231 :: saving 4018.0 to './data/2016_California_HDMA.csv'
# 00232 :: saving 4415.01 to './data/2016_California_HDMA.csv'
# 00233 :: saving 4441.0 to './data/2016_California_HDMA.csv'
# 00234 :: saving 4101.0 to './data/2016_California_HDMA.csv'
# 00235 :: saving 4215.0 to './data/2016_California_HDMA.csv'
# 00236 :: saving 4035.02 to './data/2016_California_HDMA.csv'
# 00237 :: saving 4356.02 to './data/2016_California_HDMA.csv'
# 00238 :: saving 4090.0 to './data/2016_California_HDMA.csv'
# 00239 :: saving 4514.03 to './data/2016_California_HDMA.csv'
# 00240 :: saving 4231.0 to './data/2016_California_HDMA.csv'
# 00241 :: saving 4371.01 to './data/2016_California_HDMA.csv'
# 00242 :: saving 4331.02 to './data/2016_California_HDMA.csv'
# 00243 :: saving 4507.45 to './data/2016_California_HDMA.csv'
# 00244 :: saving 4425.0 to './data/2016_California_HDMA.csv'
# 00245 :: saving 4216.0 to './data/2016_California_HDMA.csv'
# 00246 :: saving 4431.05 to './data/2016_California_HDMA.csv'
# 00247 :: saving 4414.02 to './data/2016_California_HDMA.csv'
# 00248 :: saving 4074.0 to './data/2016_California_HDMA.csv'
# 00249 :: saving 4403.06 to './data/2016_California_HDMA.csv'
# 00250 :: saving 4041.01 to './data/2016_California_HDMA.csv'
# 00251 :: saving 4417.0 to './data/2016_California_HDMA.csv'
# 00252 :: saving 4511.02 to './data/2016_California_HDMA.csv'
# 00253 :: saving 4020.0 to './data/2016_California_HDMA.csv'
# 00254 :: saving 4219.0 to './data/2016_California_HDMA.csv'
# 00255 :: saving 4322.0 to './data/2016_California_HDMA.csv'
# 00256 :: saving 4032.0 to './data/2016_California_HDMA.csv'
# 00257 :: saving 4507.52 to './data/2016_California_HDMA.csv'
# 00258 :: saving 4218.0 to './data/2016_California_HDMA.csv'
# 00259 :: saving 4426.01 to './data/2016_California_HDMA.csv'
# 00260 :: saving 4446.0 to './data/2016_California_HDMA.csv'
# 00261 :: saving 4066.02 to './data/2016_California_HDMA.csv'
# 00262 :: saving 4283.02 to './data/2016_California_HDMA.csv'
# 00263 :: saving 4029.0 to './data/2016_California_HDMA.csv'
# 00264 :: saving 4323.0 to './data/2016_California_HDMA.csv'
# 00265 :: saving 4426.0 to './data/2016_California_HDMA.csv'
# 00266 :: saving 4507.01 to './data/2016_California_HDMA.csv'
# 00267 :: saving 4433.01 to './data/2016_California_HDMA.csv'
# 00268 :: saving 4507.44 to './data/2016_California_HDMA.csv'
# 00269 :: saving 4054.0 to './data/2016_California_HDMA.csv'
# 00270 :: saving 4366.01 to './data/2016_California_HDMA.csv'
# 00271 :: saving 4512.02 to './data/2016_California_HDMA.csv'
# 00272 :: saving 4382.04 to './data/2016_California_HDMA.csv'
# 00273 :: saving 4227.0 to './data/2016_California_HDMA.csv'
# 00274 :: saving 4358.0 to './data/2016_California_HDMA.csv'
# 00275 :: saving 4507.42 to './data/2016_California_HDMA.csv'
# 00276 :: saving 4100.0 to './data/2016_California_HDMA.csv'
# 00277 :: saving 4041.0 to './data/2016_California_HDMA.csv'
# 00278 :: saving 4236.02 to './data/2016_California_HDMA.csv'
# 00279 :: saving 4515.02 to './data/2016_California_HDMA.csv'
# 00280 :: saving 4419.25 to './data/2016_California_HDMA.csv'
# 00281 :: saving 4355.0 to './data/2016_California_HDMA.csv'
# 00282 :: saving 4062.01 to './data/2016_California_HDMA.csv'
# 00283 :: saving 4338.0 to './data/2016_California_HDMA.csv'
# 00284 :: saving 4413.02 to './data/2016_California_HDMA.csv'
# 00285 :: saving 4097.0 to './data/2016_California_HDMA.csv'
# 00286 :: saving 4340.0 to './data/2016_California_HDMA.csv'
# 00287 :: saving 4507.41 to './data/2016_California_HDMA.csv'
# 00288 :: saving 4025.0 to './data/2016_California_HDMA.csv'
# 00289 :: saving 4062.02 to './data/2016_California_HDMA.csv'
# 00290 :: saving 4426.02 to './data/2016_California_HDMA.csv'
# 00291 :: saving 4052.0 to './data/2016_California_HDMA.csv'
# 00292 :: saving 4377.01 to './data/2016_California_HDMA.csv'
# 00293 :: saving 4443.01 to './data/2016_California_HDMA.csv'
# 00294 :: saving 4251.04 to './data/2016_California_HDMA.csv'
# 00295 :: saving 4066.01 to './data/2016_California_HDMA.csv'
# 00296 :: saving 4505.01 to './data/2016_California_HDMA.csv'
# 00297 :: saving 4403.33 to './data/2016_California_HDMA.csv'
# 00298 :: saving 4351.04 to './data/2016_California_HDMA.csv'
# 00299 :: saving 4086.0 to './data/2016_California_HDMA.csv'
# 00300 :: saving 4517.02 to './data/2016_California_HDMA.csv'
# 00301 :: saving 4403.09 to './data/2016_California_HDMA.csv'
# 00302 :: saving 4367.0 to './data/2016_California_HDMA.csv'
# 00303 :: saving 4517.01 to './data/2016_California_HDMA.csv'
# 00304 :: saving 4053.01 to './data/2016_California_HDMA.csv'
# 00305 :: saving 4225.0 to './data/2016_California_HDMA.csv'
# 00306 :: saving 4419.24 to './data/2016_California_HDMA.csv'
# 00307 :: saving 4354.0 to './data/2016_California_HDMA.csv'
# 00308 :: saving 4505.02 to './data/2016_California_HDMA.csv'
# 00309 :: saving 4095.0 to './data/2016_California_HDMA.csv'
# 00310 :: saving 4251.01 to './data/2016_California_HDMA.csv'
# 00311 :: saving 4333.0 to './data/2016_California_HDMA.csv'
# 00312 :: saving 4374.0 to './data/2016_California_HDMA.csv'
# 00313 :: saving 4083.0 to './data/2016_California_HDMA.csv'
# 00314 :: saving 4060.0 to './data/2016_California_HDMA.csv'
# 00315 :: saving 4515.01 to './data/2016_California_HDMA.csv'
# 00316 :: saving 4059.0 to './data/2016_California_HDMA.csv'
# 00317 :: saving 4057.0 to './data/2016_California_HDMA.csv'
# 00318 :: saving 4416.01 to './data/2016_California_HDMA.csv'
# 00319 :: saving 4303.0 to './data/2016_California_HDMA.csv'
# 00320 :: saving 4050.0 to './data/2016_California_HDMA.csv'
# 00321 :: saving 4382.01 to './data/2016_California_HDMA.csv'
# 00322 :: saving 4415.21 to './data/2016_California_HDMA.csv'
# 00323 :: saving 4305.0 to './data/2016_California_HDMA.csv'
# 00324 :: saving 4278.0 to './data/2016_California_HDMA.csv'
# 00325 :: saving 4418.0 to './data/2016_California_HDMA.csv'
# 00326 :: saving 4383.0 to './data/2016_California_HDMA.csv'
# 00327 :: saving 4507.22 to './data/2016_California_HDMA.csv'
# 00328 :: saving 4445.0 to './data/2016_California_HDMA.csv'
# 00329 :: saving 4232.0 to './data/2016_California_HDMA.csv'
# 00330 :: saving 4067.0 to './data/2016_California_HDMA.csv'
# 00331 :: saving 4506.06 to './data/2016_California_HDMA.csv'
# 00332 :: saving 4202.0 to './data/2016_California_HDMA.csv'
# 00333 :: saving 4087.0 to './data/2016_California_HDMA.csv'
# 00334 :: saving 4372.0 to './data/2016_California_HDMA.csv'
# 00335 :: saving 4102.0 to './data/2016_California_HDMA.csv'
# 00336 :: saving 4416.02 to './data/2016_California_HDMA.csv'
# 00337 :: saving 4411.0 to './data/2016_California_HDMA.csv'
# 00338 :: saving 4422.0 to './data/2016_California_HDMA.csv'
# 00339 :: saving 4360.0 to './data/2016_California_HDMA.csv'
# 00340 :: saving 4203.0 to './data/2016_California_HDMA.csv'
# 00341 :: saving 4007.0 to './data/2016_California_HDMA.csv'
# 00342 :: saving 4051.0 to './data/2016_California_HDMA.csv'
# 00343 :: saving 4506.07 to './data/2016_California_HDMA.csv'
# 00344 :: saving 4089.0 to './data/2016_California_HDMA.csv'
# 00345 :: saving 4337.0 to './data/2016_California_HDMA.csv'
# 00346 :: saving 4046.0 to './data/2016_California_HDMA.csv'
# 00347 :: saving 4274.0 to './data/2016_California_HDMA.csv'
# 00348 :: saving 4212.0 to './data/2016_California_HDMA.csv'
# 00349 :: saving 4366.02 to './data/2016_California_HDMA.csv'
# 00350 :: saving 4308.0 to './data/2016_California_HDMA.csv'
# 00351 :: saving 4412.0 to './data/2016_California_HDMA.csv'
# 00352 :: saving 4431.01 to './data/2016_California_HDMA.csv'
# 00353 :: saving 4357.0 to './data/2016_California_HDMA.csv'
# 00354 :: saving 4363.0 to './data/2016_California_HDMA.csv'
# 00355 :: saving 4384.0 to './data/2016_California_HDMA.csv'
# 00356 :: saving 4324.0 to './data/2016_California_HDMA.csv'
# 00357 :: saving 4262.0 to './data/2016_California_HDMA.csv'
# 00358 :: saving 4044.0 to './data/2016_California_HDMA.csv'
# 00359 :: saving 4286.0 to './data/2016_California_HDMA.csv'
# 00360 :: saving 4094.0 to './data/2016_California_HDMA.csv'
# 00361 :: saving 4221.0 to './data/2016_California_HDMA.csv'
# 00362 :: saving 4516.02 to './data/2016_California_HDMA.csv'
# 00363 :: saving 4336.0 to './data/2016_California_HDMA.csv'
# 00364 :: saving 4201.0 to './data/2016_California_HDMA.csv'
# 00365 :: saving 4381.0 to './data/2016_California_HDMA.csv'
# 00366 :: saving 4078.0 to './data/2016_California_HDMA.csv'
# 00367 :: saving 4507.21 to './data/2016_California_HDMA.csv'
# 00368 :: saving 4351.02 to './data/2016_California_HDMA.csv'
# 00369 :: saving 4002.0 to './data/2016_California_HDMA.csv'
# 00370 :: saving 4230.0 to './data/2016_California_HDMA.csv'
# 00371 :: saving 4047.0 to './data/2016_California_HDMA.csv'
# 00372 :: saving 4023.0 to './data/2016_California_HDMA.csv'
# 00373 :: saving 4084.0 to './data/2016_California_HDMA.csv'
# 00374 :: saving 4251.0 to './data/2016_California_HDMA.csv'
# 00375 :: saving 4040.0 to './data/2016_California_HDMA.csv'
# 00376 :: saving 4008.0 to './data/2016_California_HDMA.csv'
# 00377 :: saving 4430.01 to './data/2016_California_HDMA.csv'
# 00378 :: saving 4073.0 to './data/2016_California_HDMA.csv'
# 00379 :: saving 4376.0 to './data/2016_California_HDMA.csv'
# 00380 :: saving 4214.0 to './data/2016_California_HDMA.csv'
# 00381 :: saving 4239.01 to './data/2016_California_HDMA.csv'
# 00382 :: saving 4036.0 to './data/2016_California_HDMA.csv'
# 00383 :: saving 4403.34 to './data/2016_California_HDMA.csv'
# 00384 :: saving 4378.0 to './data/2016_California_HDMA.csv'
# 00385 :: saving 4059.02 to './data/2016_California_HDMA.csv'
# 00386 :: saving 4234.0 to './data/2016_California_HDMA.csv'
# 00387 :: saving 4284.0 to './data/2016_California_HDMA.csv'
# 00388 :: saving 4236.01 to './data/2016_California_HDMA.csv'
# 00389 :: saving 4332.0 to './data/2016_California_HDMA.csv'
# 00390 :: saving 4233.0 to './data/2016_California_HDMA.csv'
# 00391 :: saving 4446.01 to './data/2016_California_HDMA.csv'
# 00392 :: saving 4302.0 to './data/2016_California_HDMA.csv'
# 00393 :: saving 4327.0 to './data/2016_California_HDMA.csv'
# 00394 :: saving 4433.21 to './data/2016_California_HDMA.csv'
# 00395 :: saving 4325.0 to './data/2016_California_HDMA.csv'
# 00396 :: saving 4069.0 to './data/2016_California_HDMA.csv'
# 00397 :: saving 4206.0 to './data/2016_California_HDMA.csv'
# 00398 :: saving 4353.0 to './data/2016_California_HDMA.csv'
# 00399 :: saving 4033.0 to './data/2016_California_HDMA.csv'
# 00400 :: saving 4279.0 to './data/2016_California_HDMA.csv'
# 00401 :: saving 4433.02 to './data/2016_California_HDMA.csv'
# 00402 :: saving 4054.01 to './data/2016_California_HDMA.csv'
# 00403 :: saving 4506.03 to './data/2016_California_HDMA.csv'
# 00404 :: saving nan to './data/2016_California_HDMA.csv'
# 00405 :: saving 100.0 to './data/2016_California_HDMA.csv'
# 00406 :: saving nan to './data/2016_California_HDMA.csv'
# 00407 :: saving 4.02 to './data/2016_California_HDMA.csv'
# 00408 :: saving 5.0 to './data/2016_California_HDMA.csv'
# 00409 :: saving 3.01 to './data/2016_California_HDMA.csv'
# 00410 :: saving 1.02 to './data/2016_California_HDMA.csv'
# 00411 :: saving 3.02 to './data/2016_California_HDMA.csv'
# 00412 :: saving 2.0 to './data/2016_California_HDMA.csv'
# 00413 :: saving 3.03 to './data/2016_California_HDMA.csv'
# 00414 :: saving 4.01 to './data/2016_California_HDMA.csv'
# 00415 :: saving 1.01 to './data/2016_California_HDMA.csv'
# 00416 :: saving 1.0 to './data/2016_California_HDMA.csv'
# 00417 :: saving 3.04 to './data/2016_California_HDMA.csv'
# 00418 :: saving 17.02 to './data/2016_California_HDMA.csv'
# 00419 :: saving 35.02 to './data/2016_California_HDMA.csv'
# 00420 :: saving 4.01 to './data/2016_California_HDMA.csv'
# 00421 :: saving 30.01 to './data/2016_California_HDMA.csv'
# 00422 :: saving 11.0 to './data/2016_California_HDMA.csv'
# 00423 :: saving 33.0 to './data/2016_California_HDMA.csv'
# 00424 :: saving 23.0 to './data/2016_California_HDMA.csv'
# 00425 :: saving 1.02 to './data/2016_California_HDMA.csv'
# 00426 :: saving 9.01 to './data/2016_California_HDMA.csv'
# 00427 :: saving 9.03 to './data/2016_California_HDMA.csv'
# 00428 :: saving 32.0 to './data/2016_California_HDMA.csv'
# 00429 :: saving nan to './data/2016_California_HDMA.csv'
# 00430 :: saving 23.0 to './data/2016_California_HDMA.csv'
# 00431 :: saving 1.03 to './data/2016_California_HDMA.csv'
# 00432 :: saving 17.03 to './data/2016_California_HDMA.csv'
# 00433 :: saving 17.02 to './data/2016_California_HDMA.csv'
# 00434 :: saving 17.04 to './data/2016_California_HDMA.csv'
# 00435 :: saving 9.0 to './data/2016_California_HDMA.csv'
# 00436 :: saving 34.0 to './data/2016_California_HDMA.csv'
# 00437 :: saving 25.0 to './data/2016_California_HDMA.csv'
# 00438 :: saving 37.0 to './data/2016_California_HDMA.csv'
# 00439 :: saving 1.04 to './data/2016_California_HDMA.csv'
# 00440 :: saving 6.01 to './data/2016_California_HDMA.csv'
# 00441 :: saving 4.0 to './data/2016_California_HDMA.csv'
# 00442 :: saving 26.02 to './data/2016_California_HDMA.csv'
# 00443 :: saving 26.01 to './data/2016_California_HDMA.csv'
# 00444 :: saving 19.0 to './data/2016_California_HDMA.csv'
# 00445 :: saving 28.0 to './data/2016_California_HDMA.csv'
# 00446 :: saving 30.02 to './data/2016_California_HDMA.csv'
# 00447 :: saving 2.01 to './data/2016_California_HDMA.csv'
# 00448 :: saving 6.04 to './data/2016_California_HDMA.csv'
# 00449 :: saving 26.0 to './data/2016_California_HDMA.csv'
# 00450 :: saving 35.01 to './data/2016_California_HDMA.csv'
# 00451 :: saving 17.01 to './data/2016_California_HDMA.csv'
# 00452 :: saving 24.0 to './data/2016_California_HDMA.csv'
# 00453 :: saving 16.0 to './data/2016_California_HDMA.csv'
# 00454 :: saving 9.04 to './data/2016_California_HDMA.csv'
# 00455 :: saving 10.0 to './data/2016_California_HDMA.csv'
# 00456 :: saving 8.0 to './data/2016_California_HDMA.csv'
# 00457 :: saving 6.03 to './data/2016_California_HDMA.csv'
# 00458 :: saving 20.0 to './data/2016_California_HDMA.csv'
# 00459 :: saving 22.0 to './data/2016_California_HDMA.csv'
# 00460 :: saving 33.0 to './data/2016_California_HDMA.csv'
# 00461 :: saving 3.0 to './data/2016_California_HDMA.csv'
# 00462 :: saving 1.01 to './data/2016_California_HDMA.csv'
# 00463 :: saving 5.01 to './data/2016_California_HDMA.csv'
# 00464 :: saving 36.0 to './data/2016_California_HDMA.csv'
# 00465 :: saving 5.02 to './data/2016_California_HDMA.csv'
# 00466 :: saving 7.0 to './data/2016_California_HDMA.csv'
# 00467 :: saving 21.0 to './data/2016_California_HDMA.csv'
# 00468 :: saving 13.0 to './data/2016_California_HDMA.csv'
# 00469 :: saving 18.0 to './data/2016_California_HDMA.csv'
# 00470 :: saving 27.0 to './data/2016_California_HDMA.csv'
# 00471 :: saving 12.0 to './data/2016_California_HDMA.csv'
# 00472 :: saving 31.0 to './data/2016_California_HDMA.csv'
# 00473 :: saving 35.0 to './data/2016_California_HDMA.csv'
# 00474 :: saving 4.02 to './data/2016_California_HDMA.csv'
# 00475 :: saving 30.0 to './data/2016_California_HDMA.csv'
# 00476 :: saving 14.0 to './data/2016_California_HDMA.csv'
# 00477 :: saving 29.0 to './data/2016_California_HDMA.csv'
# 00478 :: saving 2.02 to './data/2016_California_HDMA.csv'
# 00479 :: saving 15.0 to './data/2016_California_HDMA.csv'
# 00480 :: saving 1.22 to './data/2016_California_HDMA.csv'
# 00481 :: saving 2.2 to './data/2016_California_HDMA.csv'
# 00482 :: saving 1.1 to './data/2016_California_HDMA.csv'
# 00483 :: saving 5.04 to './data/2016_California_HDMA.csv'
# 00484 :: saving 5.01 to './data/2016_California_HDMA.csv'
# 00485 :: saving 1.21 to './data/2016_California_HDMA.csv'
# 00486 :: saving 1.2 to './data/2016_California_HDMA.csv'
# 00487 :: saving 3.0 to './data/2016_California_HDMA.csv'
# 00488 :: saving 2.1 to './data/2016_California_HDMA.csv'
# 00489 :: saving 5.03 to './data/2016_California_HDMA.csv'
# 00490 :: saving nan to './data/2016_California_HDMA.csv'
# 00491 :: saving 5.0 to './data/2016_California_HDMA.csv'
# 00492 :: saving 4.0 to './data/2016_California_HDMA.csv'
# 00493 :: saving 1.0 to './data/2016_California_HDMA.csv'
# 00494 :: saving 2.0 to './data/2016_California_HDMA.csv'
# 00495 :: saving 4.0 to './data/2016_California_HDMA.csv'
# 00496 :: saving 3.0 to './data/2016_California_HDMA.csv'
# 00497 :: saving 5.0 to './data/2016_California_HDMA.csv'
# 00498 :: saving nan to './data/2016_California_HDMA.csv'
# 00499 :: saving 3032.0 to './data/2016_California_HDMA.csv'
# 00500 :: saving 3891.0 to './data/2016_California_HDMA.csv'
# 00501 :: saving 3910.0 to './data/2016_California_HDMA.csv'
# 00502 :: saving 3551.12 to './data/2016_California_HDMA.csv'
# 00503 :: saving 3770.0 to './data/2016_California_HDMA.csv'
# 00504 :: saving 3551.1 to './data/2016_California_HDMA.csv'
# 00505 :: saving 3591.01 to './data/2016_California_HDMA.csv'
# 00506 :: saving 3190.0 to './data/2016_California_HDMA.csv'
# 00507 :: saving 3132.02 to './data/2016_California_HDMA.csv'
# 00508 :: saving 3750.0 to './data/2016_California_HDMA.csv'
# 00509 :: saving 3230.0 to './data/2016_California_HDMA.csv'
# 00510 :: saving 3361.02 to './data/2016_California_HDMA.csv'
# 00511 :: saving 3553.02 to './data/2016_California_HDMA.csv'
# 00512 :: saving 3551.13 to './data/2016_California_HDMA.csv'
# 00513 :: saving 3522.01 to './data/2016_California_HDMA.csv'
# 00514 :: saving 3331.02 to './data/2016_California_HDMA.csv'
# 00515 :: saving 3922.0 to './data/2016_California_HDMA.csv'
# 00516 :: saving 3100.0 to './data/2016_California_HDMA.csv'
# 00517 :: saving 3131.03 to './data/2016_California_HDMA.csv'
# 00518 :: saving 3551.16 to './data/2016_California_HDMA.csv'
# 00519 :: saving 3032.02 to './data/2016_California_HDMA.csv'
# 00520 :: saving 3810.0 to './data/2016_California_HDMA.csv'
# 00521 :: saving 3440.0 to './data/2016_California_HDMA.csv'
# 00522 :: saving 3361.01 to './data/2016_California_HDMA.csv'
# 00523 :: saving 3830.0 to './data/2016_California_HDMA.csv'
# 00524 :: saving 3630.0 to './data/2016_California_HDMA.csv'
# 00525 :: saving 3031.02 to './data/2016_California_HDMA.csv'
# 00526 :: saving 3860.0 to './data/2016_California_HDMA.csv'
# 00527 :: saving 3340.06 to './data/2016_California_HDMA.csv'
# 00528 :: saving 3480.0 to './data/2016_California_HDMA.csv'
# 00529 :: saving 3720.0 to './data/2016_California_HDMA.csv'
# 00530 :: saving 3521.01 to './data/2016_California_HDMA.csv'
# 00531 :: saving 3451.12 to './data/2016_California_HDMA.csv'
# 00532 :: saving 3040.05 to './data/2016_California_HDMA.csv'
# 00533 :: saving 3620.0 to './data/2016_California_HDMA.csv'
# 00534 :: saving 3451.1 to './data/2016_California_HDMA.csv'
# 00535 :: saving 3470.0 to './data/2016_California_HDMA.csv'
# 00536 :: saving 3601.02 to './data/2016_California_HDMA.csv'
# 00537 :: saving 3671.0 to './data/2016_California_HDMA.csv'
# 00538 :: saving 3511.03 to './data/2016_California_HDMA.csv'
# 00539 :: saving 3680.01 to './data/2016_California_HDMA.csv'
# 00540 :: saving 3730.0 to './data/2016_California_HDMA.csv'
# 00541 :: saving 3451.14 to './data/2016_California_HDMA.csv'
# 00542 :: saving 3020.05 to './data/2016_California_HDMA.csv'
# 00543 :: saving 3610.0 to './data/2016_California_HDMA.csv'
# 00544 :: saving 3680.0 to './data/2016_California_HDMA.csv'
# 00545 :: saving 3020.04 to './data/2016_California_HDMA.csv'
# 00546 :: saving 3880.0 to './data/2016_California_HDMA.csv'
# 00547 :: saving 3452.04 to './data/2016_California_HDMA.csv'
# 00548 :: saving 3870.0 to './data/2016_California_HDMA.csv'
# 00549 :: saving 3020.03 to './data/2016_California_HDMA.csv'
# 00550 :: saving 3400.01 to './data/2016_California_HDMA.csv'
# 00551 :: saving 3560.02 to './data/2016_California_HDMA.csv'
# 00552 :: saving 3310.0 to './data/2016_California_HDMA.csv'
# 00553 :: saving 3211.02 to './data/2016_California_HDMA.csv'
# 00554 :: saving 3381.02 to './data/2016_California_HDMA.csv'
# 00555 :: saving 3551.07 to './data/2016_California_HDMA.csv'
# 00556 :: saving 3032.04 to './data/2016_California_HDMA.csv'
# 00557 :: saving 3132.03 to './data/2016_California_HDMA.csv'
# 00558 :: saving 3601.01 to './data/2016_California_HDMA.csv'
# 00559 :: saving 3040.01 to './data/2016_California_HDMA.csv'
# 00560 :: saving 3040.0 to './data/2016_California_HDMA.csv'
# 00561 :: saving 3270.0 to './data/2016_California_HDMA.csv'
# 00562 :: saving 3650.03 to './data/2016_California_HDMA.csv'
# 00563 :: saving 3920.0 to './data/2016_California_HDMA.csv'
# 00564 :: saving 3390.02 to './data/2016_California_HDMA.csv'
# 00565 :: saving 3160.0 to './data/2016_California_HDMA.csv'
# 00566 :: saving 3790.0 to './data/2016_California_HDMA.csv'
# 00567 :: saving 3530.01 to './data/2016_California_HDMA.csv'
# 00568 :: saving 3032.0 to './data/2016_California_HDMA.csv'
# 00569 :: saving 3451.11 to './data/2016_California_HDMA.csv'
# 00570 :: saving 3923.0 to './data/2016_California_HDMA.csv'
# 00571 :: saving 3240.01 to './data/2016_California_HDMA.csv'
# 00572 :: saving 3462.03 to './data/2016_California_HDMA.csv'
# 00573 :: saving 3551.11 to './data/2016_California_HDMA.csv'
# 00574 :: saving 3240.02 to './data/2016_California_HDMA.csv'
# 00575 :: saving 3511.01 to './data/2016_California_HDMA.csv'
# 00576 :: saving 3601.0 to './data/2016_California_HDMA.csv'
# 00577 :: saving 3852.0 to './data/2016_California_HDMA.csv'
# 00578 :: saving 3211.03 to './data/2016_California_HDMA.csv'
# 00579 :: saving 3551.17 to './data/2016_California_HDMA.csv'
# 00580 :: saving nan to './data/2016_California_HDMA.csv'
# 00581 :: saving 3071.01 to './data/2016_California_HDMA.csv'
# 00582 :: saving 3340.03 to './data/2016_California_HDMA.csv'
# 00583 :: saving 3141.04 to './data/2016_California_HDMA.csv'
# 00584 :: saving 3020.07 to './data/2016_California_HDMA.csv'
# 00585 :: saving 3240.0 to './data/2016_California_HDMA.csv'
# 00586 :: saving 3132.04 to './data/2016_California_HDMA.csv'
# 00587 :: saving 3132.01 to './data/2016_California_HDMA.csv'
# 00588 :: saving 3511.02 to './data/2016_California_HDMA.csv'
# 00589 :: saving 3451.15 to './data/2016_California_HDMA.csv'
# 00590 :: saving 3331.01 to './data/2016_California_HDMA.csv'
# 00591 :: saving 3381.0 to './data/2016_California_HDMA.csv'
# 00592 :: saving 3511.0 to './data/2016_California_HDMA.csv'
# 00593 :: saving 3032.03 to './data/2016_California_HDMA.csv'
# 00594 :: saving 3700.0 to './data/2016_California_HDMA.csv'
# 00595 :: saving 3672.0 to './data/2016_California_HDMA.csv'
# 00596 :: saving 3560.01 to './data/2016_California_HDMA.csv'
# 00597 :: saving 3690.01 to './data/2016_California_HDMA.csv'
# 00598 :: saving 3800.0 to './data/2016_California_HDMA.csv'
# 00599 :: saving 3851.0 to './data/2016_California_HDMA.csv'
# 00600 :: saving 3362.0 to './data/2016_California_HDMA.csv'
# 00601 :: saving 3131.02 to './data/2016_California_HDMA.csv'
# 00602 :: saving 3040.03 to './data/2016_California_HDMA.csv'
# 00603 :: saving 3350.0 to './data/2016_California_HDMA.csv'
# 00604 :: saving 3032.01 to './data/2016_California_HDMA.csv'
# 00605 :: saving 3892.0 to './data/2016_California_HDMA.csv'
# 00606 :: saving 3040.04 to './data/2016_California_HDMA.csv'
# 00607 :: saving 3080.01 to './data/2016_California_HDMA.csv'
# 00608 :: saving 3383.01 to './data/2016_California_HDMA.csv'
# 00609 :: saving 3382.04 to './data/2016_California_HDMA.csv'
# 00610 :: saving 3170.0 to './data/2016_California_HDMA.csv'
# 00611 :: saving 3383.02 to './data/2016_California_HDMA.csv'
# 00612 :: saving 3430.01 to './data/2016_California_HDMA.csv'
# 00613 :: saving 3072.01 to './data/2016_California_HDMA.csv'
# 00614 :: saving 3290.0 to './data/2016_California_HDMA.csv'
# 00615 :: saving 3211.01 to './data/2016_California_HDMA.csv'
# 00616 :: saving 3060.04 to './data/2016_California_HDMA.csv'
# 00617 :: saving 3462.01 to './data/2016_California_HDMA.csv'
# 00618 :: saving 3591.05 to './data/2016_California_HDMA.csv'
# 00619 :: saving 3040.02 to './data/2016_California_HDMA.csv'
# 00620 :: saving 3451.09 to './data/2016_California_HDMA.csv'
# 00621 :: saving 3451.08 to './data/2016_California_HDMA.csv'
# 00622 :: saving 3031.03 to './data/2016_California_HDMA.csv'
# 00623 :: saving 3490.0 to './data/2016_California_HDMA.csv'
# 00624 :: saving 3780.0 to './data/2016_California_HDMA.csv'
# 00625 :: saving 3592.03 to './data/2016_California_HDMA.csv'
# 00626 :: saving 3340.05 to './data/2016_California_HDMA.csv'
# 00627 :: saving 3180.0 to './data/2016_California_HDMA.csv'
# 00628 :: saving 3551.14 to './data/2016_California_HDMA.csv'
# 00629 :: saving 3602.0 to './data/2016_California_HDMA.csv'
# 00630 :: saving 3060.02 to './data/2016_California_HDMA.csv'
# 00631 :: saving 3660.01 to './data/2016_California_HDMA.csv'
# 00632 :: saving 3740.0 to './data/2016_California_HDMA.csv'
# 00633 :: saving 3410.0 to './data/2016_California_HDMA.csv'
# 00634 :: saving 3141.03 to './data/2016_California_HDMA.csv'
# 00635 :: saving 3072.05 to './data/2016_California_HDMA.csv'
# 00636 :: saving 3200.03 to './data/2016_California_HDMA.csv'
# 00637 :: saving 3132.06 to './data/2016_California_HDMA.csv'
# 00638 :: saving 3362.02 to './data/2016_California_HDMA.csv'
# 00639 :: saving 3390.01 to './data/2016_California_HDMA.csv'
# 00640 :: saving 3461.01 to './data/2016_California_HDMA.csv'
# 00641 :: saving 3420.0 to './data/2016_California_HDMA.csv'
# 00642 :: saving 3551.15 to './data/2016_California_HDMA.csv'
# 00643 :: saving 3840.0 to './data/2016_California_HDMA.csv'
# 00644 :: saving 3451.05 to './data/2016_California_HDMA.csv'
# 00645 :: saving 3382.02 to './data/2016_California_HDMA.csv'
# 00646 :: saving 3132.05 to './data/2016_California_HDMA.csv'
# 00647 :: saving 3760.0 to './data/2016_California_HDMA.csv'
# 00648 :: saving 3090.0 to './data/2016_California_HDMA.csv'
# 00649 :: saving 3640.01 to './data/2016_California_HDMA.csv'
# 00650 :: saving 3200.02 to './data/2016_California_HDMA.csv'
# 00651 :: saving 3553.06 to './data/2016_California_HDMA.csv'
# 00652 :: saving 3580.0 to './data/2016_California_HDMA.csv'
# 00653 :: saving 3342.0 to './data/2016_California_HDMA.csv'
# 00654 :: saving 3020.06 to './data/2016_California_HDMA.csv'
# 00655 :: saving 3150.0 to './data/2016_California_HDMA.csv'
# 00656 :: saving 3592.04 to './data/2016_California_HDMA.csv'
# 00657 :: saving 3452.02 to './data/2016_California_HDMA.csv'
# 00658 :: saving 3072.04 to './data/2016_California_HDMA.csv'
# 00659 :: saving 3340.01 to './data/2016_California_HDMA.csv'
# 00660 :: saving 3072.02 to './data/2016_California_HDMA.csv'
# 00661 :: saving 3551.01 to './data/2016_California_HDMA.csv'
# 00662 :: saving 3372.0 to './data/2016_California_HDMA.csv'
# 00663 :: saving 3080.02 to './data/2016_California_HDMA.csv'
# 00664 :: saving 3551.09 to './data/2016_California_HDMA.csv'
# 00665 :: saving 3430.02 to './data/2016_California_HDMA.csv'
# 00666 :: saving 3141.02 to './data/2016_California_HDMA.csv'
# 00667 :: saving 3120.0 to './data/2016_California_HDMA.csv'
# 00668 :: saving 3032.05 to './data/2016_California_HDMA.csv'
# 00669 :: saving 3332.0 to './data/2016_California_HDMA.csv'
# 00670 :: saving 3553.01 to './data/2016_California_HDMA.csv'
# 00671 :: saving 3331.0 to './data/2016_California_HDMA.csv'
# 00672 :: saving 3200.04 to './data/2016_California_HDMA.csv'
# 00673 :: saving 3650.02 to './data/2016_California_HDMA.csv'
# 00674 :: saving 3551.06 to './data/2016_California_HDMA.csv'
# 00675 :: saving 3570.0 to './data/2016_California_HDMA.csv'
# 00676 :: saving 3381.01 to './data/2016_California_HDMA.csv'
# 00677 :: saving 3500.0 to './data/2016_California_HDMA.csv'
# 00678 :: saving 3382.03 to './data/2016_California_HDMA.csv'
# 00679 :: saving 3320.0 to './data/2016_California_HDMA.csv'
# 00680 :: saving 3373.0 to './data/2016_California_HDMA.csv'
# 00681 :: saving 3551.04 to './data/2016_California_HDMA.csv'
# 00682 :: saving 3020.09 to './data/2016_California_HDMA.csv'
# 00683 :: saving 3110.0 to './data/2016_California_HDMA.csv'
# 00684 :: saving 3461.02 to './data/2016_California_HDMA.csv'
# 00685 :: saving 3451.16 to './data/2016_California_HDMA.csv'
# 00686 :: saving 3902.0 to './data/2016_California_HDMA.csv'
# 00687 :: saving 3340.04 to './data/2016_California_HDMA.csv'
# 00688 :: saving 3591.02 to './data/2016_California_HDMA.csv'
# 00689 :: saving 3462.04 to './data/2016_California_HDMA.csv'
# 00690 :: saving 3640.02 to './data/2016_California_HDMA.csv'
# 00691 :: saving 3060.03 to './data/2016_California_HDMA.csv'
# 00692 :: saving 3071.02 to './data/2016_California_HDMA.csv'
# 00693 :: saving 3551.08 to './data/2016_California_HDMA.csv'
# 00694 :: saving 3452.01 to './data/2016_California_HDMA.csv'
# 00695 :: saving 3680.02 to './data/2016_California_HDMA.csv'
# 00696 :: saving 3521.02 to './data/2016_California_HDMA.csv'
# 00697 :: saving 3592.02 to './data/2016_California_HDMA.csv'
# 00698 :: saving 3142.0 to './data/2016_California_HDMA.csv'
# 00699 :: saving 3462.02 to './data/2016_California_HDMA.csv'
# 00700 :: saving 3553.04 to './data/2016_California_HDMA.csv'
# 00701 :: saving 3020.02 to './data/2016_California_HDMA.csv'
# 00702 :: saving 3512.0 to './data/2016_California_HDMA.csv'
# 00703 :: saving 3591.04 to './data/2016_California_HDMA.csv'
# 00704 :: saving 3540.02 to './data/2016_California_HDMA.csv'
# 00705 :: saving 3522.02 to './data/2016_California_HDMA.csv'
# 00706 :: saving 3540.01 to './data/2016_California_HDMA.csv'
# 00707 :: saving 3362.01 to './data/2016_California_HDMA.csv'
# 00708 :: saving 3400.02 to './data/2016_California_HDMA.csv'
# 00709 :: saving 3530.02 to './data/2016_California_HDMA.csv'
# 00710 :: saving 3220.0 to './data/2016_California_HDMA.csv'
# 00711 :: saving 3451.03 to './data/2016_California_HDMA.csv'
# 00712 :: saving 3553.05 to './data/2016_California_HDMA.csv'
# 00713 :: saving 3250.0 to './data/2016_California_HDMA.csv'
# 00714 :: saving 3660.02 to './data/2016_California_HDMA.csv'
# 00715 :: saving 3901.0 to './data/2016_California_HDMA.csv'
# 00716 :: saving 3031.0 to './data/2016_California_HDMA.csv'
# 00717 :: saving 3382.01 to './data/2016_California_HDMA.csv'
# 00718 :: saving 3451.01 to './data/2016_California_HDMA.csv'
# 00719 :: saving 3820.0 to './data/2016_California_HDMA.csv'
# 00720 :: saving 3690.02 to './data/2016_California_HDMA.csv'
# 00721 :: saving 3430.03 to './data/2016_California_HDMA.csv'
# 00722 :: saving 3371.0 to './data/2016_California_HDMA.csv'
# 00723 :: saving 3131.01 to './data/2016_California_HDMA.csv'
# 00724 :: saving 3020.1 to './data/2016_California_HDMA.csv'
# 00725 :: saving 3553.03 to './data/2016_California_HDMA.csv'
# 00726 :: saving 3280.0 to './data/2016_California_HDMA.csv'
# 00727 :: saving 3060.01 to './data/2016_California_HDMA.csv'
# 00728 :: saving 3050.0 to './data/2016_California_HDMA.csv'
# 00729 :: saving 3390.0 to './data/2016_California_HDMA.csv'
# 00730 :: saving 3570.0 to './data/2016_California_HDMA.csv'
# 00731 :: saving 3710.0 to './data/2016_California_HDMA.csv'
# 00732 :: saving 3591.03 to './data/2016_California_HDMA.csv'
# 00733 :: saving 3200.01 to './data/2016_California_HDMA.csv'
# 00734 :: saving 3300.0 to './data/2016_California_HDMA.csv'
# 00735 :: saving 3010.0 to './data/2016_California_HDMA.csv'
# 00736 :: saving 3212.0 to './data/2016_California_HDMA.csv'
# 00737 :: saving 3020.08 to './data/2016_California_HDMA.csv'
# 00738 :: saving 3552.0 to './data/2016_California_HDMA.csv'
# 00739 :: saving 3451.02 to './data/2016_California_HDMA.csv'
# 00740 :: saving 3452.03 to './data/2016_California_HDMA.csv'
# 00741 :: saving 3451.13 to './data/2016_California_HDMA.csv'
# 00742 :: saving 3451.07 to './data/2016_California_HDMA.csv'
# 00743 :: saving 3650.01 to './data/2016_California_HDMA.csv'
# 00744 :: saving 3260.0 to './data/2016_California_HDMA.csv'
# 00745 :: saving 1.01 to './data/2016_California_HDMA.csv'
# 00746 :: saving 2.01 to './data/2016_California_HDMA.csv'
# 00747 :: saving 1.02 to './data/2016_California_HDMA.csv'
# 00748 :: saving 1.04 to './data/2016_California_HDMA.csv'
# 00749 :: saving nan to './data/2016_California_HDMA.csv'
# 00750 :: saving 2.03 to './data/2016_California_HDMA.csv'
# 00751 :: saving 1.05 to './data/2016_California_HDMA.csv'
# 00752 :: saving 2.02 to './data/2016_California_HDMA.csv'
# 00753 :: saving 1.03 to './data/2016_California_HDMA.csv'
# 00754 :: saving 312.0 to './data/2016_California_HDMA.csv'
# 00755 :: saving 301.01 to './data/2016_California_HDMA.csv'
# 00756 :: saving 303.01 to './data/2016_California_HDMA.csv'
# 00757 :: saving 315.04 to './data/2016_California_HDMA.csv'
# 00758 :: saving 308.04 to './data/2016_California_HDMA.csv'
# 00759 :: saving 314.05 to './data/2016_California_HDMA.csv'
# 00760 :: saving 308.08 to './data/2016_California_HDMA.csv'
# 00761 :: saving 307.09 to './data/2016_California_HDMA.csv'
# 00762 :: saving 318.0 to './data/2016_California_HDMA.csv'
# 00763 :: saving 317.0 to './data/2016_California_HDMA.csv'
# 00764 :: saving 316.0 to './data/2016_California_HDMA.csv'
# 00765 :: saving nan to './data/2016_California_HDMA.csv'
# 00766 :: saving 306.02 to './data/2016_California_HDMA.csv'
# 00767 :: saving 314.03 to './data/2016_California_HDMA.csv'
# 00768 :: saving 306.01 to './data/2016_California_HDMA.csv'
# 00769 :: saving 310.0 to './data/2016_California_HDMA.csv'
# 00770 :: saving 305.05 to './data/2016_California_HDMA.csv'
# 00771 :: saving 308.1 to './data/2016_California_HDMA.csv'
# 00772 :: saving 320.0 to './data/2016_California_HDMA.csv'
# 00773 :: saving 308.06 to './data/2016_California_HDMA.csv'
# 00774 :: saving 305.04 to './data/2016_California_HDMA.csv'
# 00775 :: saving 308.03 to './data/2016_California_HDMA.csv'
# 00776 :: saving 311.0 to './data/2016_California_HDMA.csv'
# 00777 :: saving 303.02 to './data/2016_California_HDMA.csv'
# 00778 :: saving 304.01 to './data/2016_California_HDMA.csv'
# 00779 :: saving 307.01 to './data/2016_California_HDMA.csv'
# 00780 :: saving 306.03 to './data/2016_California_HDMA.csv'
# 00781 :: saving 313.01 to './data/2016_California_HDMA.csv'
# 00782 :: saving 314.02 to './data/2016_California_HDMA.csv'
# 00783 :: saving 314.06 to './data/2016_California_HDMA.csv'
# 00784 :: saving 305.03 to './data/2016_California_HDMA.csv'
# 00785 :: saving 310.0 to './data/2016_California_HDMA.csv'
# 00786 :: saving 314.04 to './data/2016_California_HDMA.csv'
# 00787 :: saving 302.0 to './data/2016_California_HDMA.csv'
# 00788 :: saving 309.02 to './data/2016_California_HDMA.csv'
# 00789 :: saving 315.03 to './data/2016_California_HDMA.csv'
# 00790 :: saving 301.02 to './data/2016_California_HDMA.csv'
# 00791 :: saving 307.06 to './data/2016_California_HDMA.csv'
# 00792 :: saving 308.09 to './data/2016_California_HDMA.csv'
# 00793 :: saving 307.1 to './data/2016_California_HDMA.csv'
# 00794 :: saving 315.02 to './data/2016_California_HDMA.csv'
# 00795 :: saving 308.07 to './data/2016_California_HDMA.csv'
# 00796 :: saving 305.01 to './data/2016_California_HDMA.csv'
# 00797 :: saving 308.05 to './data/2016_California_HDMA.csv'
# 00798 :: saving 307.03 to './data/2016_California_HDMA.csv'
# ...
# 01843 :: saving 6505.02 to './data/2016_California_HDMA.csv'
# 01844 :: saving 2124.1 to './data/2016_California_HDMA.csv'
# 01845 :: saving 2091.04 to './data/2016_California_HDMA.csv'
# 01846 :: saving 1991.2 to './data/2016_California_HDMA.csv'
# 01847 :: saving 4824.01 to './data/2016_California_HDMA.csv'
# 01848 :: saving 4053.02 to './data/2016_California_HDMA.csv'
# 01849 :: saving 5535.04 to './data/2016_California_HDMA.csv'
# 01850 :: saving 4307.01 to './data/2016_California_HDMA.csv'
# 01851 :: saving 9800.21 to './data/2016_California_HDMA.csv'
# 01852 :: saving 9006.05 to './data/2016_California_HDMA.csv'
# 01853 :: saving 5344.06 to './data/2016_California_HDMA.csv'
# 01854 :: saving 4309.02 to './data/2016_California_HDMA.csv'
# 01855 :: saving 5545.15 to './data/2016_California_HDMA.csv'
# 01856 :: saving 5352.0 to './data/2016_California_HDMA.csv'
# 01857 :: saving 5717.04 to './data/2016_California_HDMA.csv'
# 01858 :: saving 2133.2 to './data/2016_California_HDMA.csv'
# 01859 :: saving 4045.04 to './data/2016_California_HDMA.csv'
# 01860 :: saving 9010.04 to './data/2016_California_HDMA.csv'
# 01861 :: saving 6703.26 to './data/2016_California_HDMA.csv'
# 01862 :: saving 2699.07 to './data/2016_California_HDMA.csv'
# 01863 :: saving 6200.02 to './data/2016_California_HDMA.csv'
# 01864 :: saving 4309.01 to './data/2016_California_HDMA.csv'
# 01865 :: saving 6028.02 to './data/2016_California_HDMA.csv'
# 01866 :: saving 3107.03 to './data/2016_California_HDMA.csv'
# 01867 :: saving 5418.02 to './data/2016_California_HDMA.csv'
# 01868 :: saving 1081.04 to './data/2016_California_HDMA.csv'
# 01869 :: saving 9800.24 to './data/2016_California_HDMA.csv'
# 01870 :: saving 9001.04 to './data/2016_California_HDMA.csv'
# 01871 :: saving 5734.01 to './data/2016_California_HDMA.csv'
# 01872 :: saving 5343.01 to './data/2016_California_HDMA.csv'
# 01873 :: saving 1031.01 to './data/2016_California_HDMA.csv'
# 01874 :: saving 5041.01 to './data/2016_California_HDMA.csv'
# 01875 :: saving 1832.21 to './data/2016_California_HDMA.csv'
# 01876 :: saving 1241.01 to './data/2016_California_HDMA.csv'
# 01877 :: saving 8005.06 to './data/2016_California_HDMA.csv'
# 01878 :: saving 5039.01 to './data/2016_California_HDMA.csv'
# 01879 :: saving 2118.04 to './data/2016_California_HDMA.csv'
# 01880 :: saving 2696.02 to './data/2016_California_HDMA.csv'
# 01881 :: saving 1891.01 to './data/2016_California_HDMA.csv'
# 01882 :: saving 5402.03 to './data/2016_California_HDMA.csv'
# 01883 :: saving 5437.02 to './data/2016_California_HDMA.csv'
# 01884 :: saving 5361.03 to './data/2016_California_HDMA.csv'
# 01885 :: saving 5020.04 to './data/2016_California_HDMA.csv'
# 01886 :: saving 9107.15 to './data/2016_California_HDMA.csv'
# 01887 :: saving 6025.02 to './data/2016_California_HDMA.csv'
# 01888 :: saving 1863.02 to './data/2016_California_HDMA.csv'
# 01889 :: saving 5326.03 to './data/2016_California_HDMA.csv'
# 01890 :: saving 1154.03 to './data/2016_California_HDMA.csv'
# 01891 :: saving 5356.05 to './data/2016_California_HDMA.csv'
# 01892 :: saving 4329.01 to './data/2016_California_HDMA.csv'
# 01893 :: saving 7017.01 to './data/2016_California_HDMA.csv'
# 01894 :: saving 2976.02 to './data/2016_California_HDMA.csv'
# 01895 :: saving 8004.06 to './data/2016_California_HDMA.csv'
# 01896 :: saving 1861.0 to './data/2016_California_HDMA.csv'
# 01897 :: saving 4029.01 to './data/2016_California_HDMA.csv'
# 01898 :: saving 2412.0 to './data/2016_California_HDMA.csv'
# 01899 :: saving 1041.24 to './data/2016_California_HDMA.csv'
# 01900 :: saving 2372.0 to './data/2016_California_HDMA.csv'
# 01901 :: saving 4825.21 to './data/2016_California_HDMA.csv'
# 01902 :: saving 2734.02 to './data/2016_California_HDMA.csv'
# 01903 :: saving 2780.01 to './data/2016_California_HDMA.csv'
# 01904 :: saving 9800.08 to './data/2016_California_HDMA.csv'
# 01905 :: saving 6033.01 to './data/2016_California_HDMA.csv'
# 01906 :: saving 4080.06 to './data/2016_California_HDMA.csv'
# 01907 :: saving 5755.0 to './data/2016_California_HDMA.csv'
# 01908 :: saving 2213.04 to './data/2016_California_HDMA.csv'
# 01909 :: saving 6206.02 to './data/2016_California_HDMA.csv'
# 01910 :: saving 1959.02 to './data/2016_California_HDMA.csv'
# 01911 :: saving 1276.05 to './data/2016_California_HDMA.csv'
# 01912 :: saving 2397.02 to './data/2016_California_HDMA.csv'
# 01913 :: saving 2212.1 to './data/2016_California_HDMA.csv'
# 01914 :: saving 2270.1 to './data/2016_California_HDMA.csv'
# 01915 :: saving 1340.01 to './data/2016_California_HDMA.csv'
# 01916 :: saving 7015.01 to './data/2016_California_HDMA.csv'
# 01917 :: saving 3012.05 to './data/2016_California_HDMA.csv'
# 01918 :: saving 1288.01 to './data/2016_California_HDMA.csv'
# 01919 :: saving 4338.01 to './data/2016_California_HDMA.csv'
# 01920 :: saving 2742.02 to './data/2016_California_HDMA.csv'
# 01921 :: saving 1066.45 to './data/2016_California_HDMA.csv'
# 01922 :: saving 9203.37 to './data/2016_California_HDMA.csv'
# 01923 :: saving 2162.0 to './data/2016_California_HDMA.csv'
# 01924 :: saving 1320.01 to './data/2016_California_HDMA.csv'
# 01925 :: saving 4075.01 to './data/2016_California_HDMA.csv'
# 01926 :: saving 1883.0 to './data/2016_California_HDMA.csv'
# 01927 :: saving 4067.01 to './data/2016_California_HDMA.csv'
# 01928 :: saving 2656.02 to './data/2016_California_HDMA.csv'
# 01929 :: saving 5763.01 to './data/2016_California_HDMA.csv'
# 01930 :: saving 2014.01 to './data/2016_California_HDMA.csv'
# 01931 :: saving 3023.02 to './data/2016_California_HDMA.csv'
# 01932 :: saving 1241.03 to './data/2016_California_HDMA.csv'
# 01933 :: saving 5004.03 to './data/2016_California_HDMA.csv'
# 01934 :: saving 5330.02 to './data/2016_California_HDMA.csv'
# 01935 :: saving 9200.37 to './data/2016_California_HDMA.csv'
# 01936 :: saving 5512.01 to './data/2016_California_HDMA.csv'
# 01937 :: saving 2037.2 to './data/2016_California_HDMA.csv'
# 01938 :: saving 3004.0 to './data/2016_California_HDMA.csv'
# 01939 :: saving 5776.02 to './data/2016_California_HDMA.csv'
# 01940 :: saving 3018.02 to './data/2016_California_HDMA.csv'
# 01941 :: saving 6700.03 to './data/2016_California_HDMA.csv'
# 01942 :: saving 1239.01 to './data/2016_California_HDMA.csv'
# 01943 :: saving 3016.01 to './data/2016_California_HDMA.csv'
# 01944 :: saving 2675.02 to './data/2016_California_HDMA.csv'
# 01945 :: saving 9200.26 to './data/2016_California_HDMA.csv'
# 01946 :: saving 2371.02 to './data/2016_California_HDMA.csv'
# 01947 :: saving 1912.01 to './data/2016_California_HDMA.csv'
# 01948 :: saving 1278.06 to './data/2016_California_HDMA.csv'
# 01949 :: saving 1154.04 to './data/2016_California_HDMA.csv'
# 01950 :: saving 9200.4 to './data/2016_California_HDMA.csv'
# 01951 :: saving 1881.0 to './data/2016_California_HDMA.csv'
# 01952 :: saving 4076.0 to './data/2016_California_HDMA.csv'
# 01953 :: saving 1912.04 to './data/2016_California_HDMA.csv'
# 01954 :: saving 4600.0 to './data/2016_California_HDMA.csv'
# 01955 :: saving 5775.04 to './data/2016_California_HDMA.csv'
# 01956 :: saving 1210.1 to './data/2016_California_HDMA.csv'
# 01957 :: saving 9010.05 to './data/2016_California_HDMA.csv'
# 01958 :: saving 5361.02 to './data/2016_California_HDMA.csv'
# 01959 :: saving 5425.01 to './data/2016_California_HDMA.csv'
# 01960 :: saving 4807.04 to './data/2016_California_HDMA.csv'
# 01961 :: saving 4303.01 to './data/2016_California_HDMA.csv'
# 01962 :: saving 2220.0 to './data/2016_California_HDMA.csv'
# 01963 :: saving 6209.02 to './data/2016_California_HDMA.csv'
# 01964 :: saving 2324.0 to './data/2016_California_HDMA.csv'
# 01965 :: saving 4808.03 to './data/2016_California_HDMA.csv'
# 01966 :: saving 1065.2 to './data/2016_California_HDMA.csv'
# 01967 :: saving 3025.06 to './data/2016_California_HDMA.csv'
# 01968 :: saving 4335.04 to './data/2016_California_HDMA.csv'
# 01969 :: saving 2197.0 to './data/2016_California_HDMA.csv'
# 01970 :: saving 5775.02 to './data/2016_California_HDMA.csv'
# 01971 :: saving 6030.05 to './data/2016_California_HDMA.csv'
# 01972 :: saving 5731.0 to './data/2016_California_HDMA.csv'
# 01973 :: saving 5519.0 to './data/2016_California_HDMA.csv'
# 01974 :: saving 1852.03 to './data/2016_California_HDMA.csv'
# 01975 :: saving 1832.22 to './data/2016_California_HDMA.csv'
# 01976 :: saving 1097.0 to './data/2016_California_HDMA.csv'
# 01977 :: saving 9102.04 to './data/2016_California_HDMA.csv'
# 01978 :: saving 5527.0 to './data/2016_California_HDMA.csv'
# 01979 :: saving 1902.02 to './data/2016_California_HDMA.csv'
# 01980 :: saving 2656.0 to './data/2016_California_HDMA.csv'
# 01981 :: saving 1920.01 to './data/2016_California_HDMA.csv'
# 01982 :: saving 4057.01 to './data/2016_California_HDMA.csv'
# 01983 :: saving 1066.05 to './data/2016_California_HDMA.csv'
# 01984 :: saving 9302.0 to './data/2016_California_HDMA.csv'
# 01985 :: saving 5749.02 to './data/2016_California_HDMA.csv'
# 01986 :: saving 1132.31 to './data/2016_California_HDMA.csv'
# 01987 :: saving 2112.02 to './data/2016_California_HDMA.csv'
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self, block)
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self)
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:777)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='api.consumerfinance.gov', port=443): Max retries exceeded with url: /data/hmda/slice/hmda_lar.json?$where=state_code=6+AND+county_code=037+AND+census_tract_number=%224087.03%22&$limit=250000&$offset=0 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:777)'),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-6-7e8c68f920dd> in <module>()
#      22     while True:
#      23         url = url_template.format(state_code, county_code, census_tract_number, page_size, offset)
# ---> 24         response = requests.get(url).json()
#      25         if response is None or response.get('results') is None:
#      26             continue
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/Desktop/Repositories/SIM/DataMining/.dma/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.consumerfinance.gov', port=443): Max retries exceeded with url: /data/hmda/slice/hmda_lar.json?$where=state_code=6+AND+county_code=037+AND+census_tract_number=%224087.03%22&$limit=250000&$offset=0 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:777)'),))
