# %%
# importing libraries
import pandas as pd
import numpy as np

df = pd.read_csv('Yelp_Reviews.csv')

# %% [markdown]
# # DMA Assignment 1 - Data Preprocessing
#
# Data transformations are useful for preparing a dataset for answering a particular question. Part of this process involves generating features from the dataset you find relevant to the question at hand. For this lab, we will be using a Yelp reviews dataset. Each row in the dataset depicts one review along with the features of the review (the reviewer, the review text, etc.). The goal of this lab is to convert this reviews dataset into a reviewers dataset by creating different features of each reviewer.
#
# The submission for this assignment should be done *individually*, although you are allowed to work in groups of 2.
#
# The submission should be a zip file that includes (1) your code and (2) your single custom feature in csv format (with a column header equal to the description of the feature). Your code can be provided in one of two ways (a) a python file named qN.py which produces avg statistics for each question in the lab, where you replace N with the lab question number or (b) a single ipython notebook that clearly identifies the rows (with comments) of the notebook used to generate statistics for the respective question in the lab.

# %% [markdown]
# ### Lab Questions:
#
# Data: [Yelp Reviews](https://drive.google.com/open?id=1KfdYRu2Zz6amSD7EKXw9p2cyF8mG6_og)
#
#
# The first two questions are creating features of the yelp business while the rest of the questions are generating features of the reviewer. The first two questions include the solution, which you can adapt.
#
# Generate the following values, which are as per business_id to get started:
# 1. **What was the highest number of reviews for any one business_id?**
#    - For this task, we will need to group the reviews dataset by business_id. This will aggregate data for each business, which is what we need. This can be done using [groupby](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html).
#     - ```yelp_businesses = yelp_dataset.groupby('business_id').size() ```
#     - The .size() counts the number of instances for each business_id, which gives us the number of reviews as each instance in this dataset is a review.
#     - The following command will sort this list, after which you can take note of the highest value: ```sorted_yelp_businesses = yelp_businesses.sort(ascending=False,inplace=False)```
#     - This approach allows you to see the data structure being used in the sort. A quicker approach to getting the max would be to use the max function: ```max(yelp_businesses)```
# <br>
# <br>
# 2. **What was the average number of reviews for a business_id?**
#     - ```yelp_businesses.mean()```
# <br>
# <br>
#
# 1. **_Generate the following values, which are as per reviewer:_**
#     1. What is the average number of reviews per reviewer?
#     1. What is the average number of cool votes per reviewer?
#     1. What is the average number of funny votes per reviewer?
#     1. What is the average number of useful votes per reviewer?
#     <br>
#     <br>
#     1. What is the average of the log of the number of reviews per reviewer?
#         - find the average of the feature vector by first taking the natural log of each entry and then calculating the average. You will have to handle the log of `0` when a reviewer has no votes in that category. The log of `0` is `-Inf`. Replace `-Inf` with `NaN` (Not a Number) and omit these instances when calculating the average.
#     1. What is the average of the log of the number of cool votes per reviewer?
#     1. What is the average of the log of the number of funny votes per reviewer?
#     1. What is the average of the log of the number of useful votes per reviewer?
#     <br>
#     <br>
#     1. Find the average of the percentage of total cool votes out of total votes for each reviewer.
#     1. Find the average of the percentage of total funny votes out of total votes for each reviewer.
#     1. Find the average of the percentage of total useful votes out of total votes for each reviewer.
#     <br>
#     <br>
#     1. Average review text length (in non-space characters)
#     1. Year in which the reviewer wrote the most reviews. Once you have this for each reviewer, subtract the minimum possible year (2005) from each so that your final feature values are 0, 1, 2 etc.
#
# _Note: this feature is helpful in determining the distance between reviewers in terms of when they were most active
# Average review text length (in characters)_
#
# **Come up with a new feature.**
#    - Fill in your own column `*group_name*_feature` with a unique feature.
#    - Create the code and feature output for this custom feature.
#
# Note: keep in mind that the output should have as many lines as reviewers. The output file should be CSV  with two columns (1) the user ID and (2) your hand crafted feature. Add a description/header for the two features as the first line of the file. Pandas has a helpful function called “to_csv” that you can utilize to output this feature.
#
# DONE! All lab submission materials are due next Thursday at 1:59 AM..

# %%
df
# Out:
#           type             business_id                 user_id  stars  \
# 0       review  mxrXVZWc6PWk81gvOVNOUw  mv7shusL4Xb6TylVYBv4CA      4
# 1       review  mxrXVZWc6PWk81gvOVNOUw  0aN5QPhs-VwK2vusKG0waQ      5
# 2       review  kK4AzZ0YWI-U2G-paAL7Fg  0aN5QPhs-VwK2vusKG0waQ      5
# 3       review  mxrXVZWc6PWk81gvOVNOUw  1JUwyYab-uJzEx_FRd81Zg      5
# 4       review  mxrXVZWc6PWk81gvOVNOUw  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 5       review  iDYzGVIF1TDWdjHNgNjCVw  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 6       review  dsMvINhoQbIQgSRTBv2B6g  2Zd3Xy8hUVmZkNg7RyNjhg      3
# 7       review  ZXRcWs5SUCvSfb8I2aLOnA  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 8       review  YQvg0JCGRFUkb6reMMf3Iw  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 9       review  GGVcdnKoRXldVEgergSF-A  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 10      review  1Q_H3BLhKBymF6Se8FfZNw  2Zd3Xy8hUVmZkNg7RyNjhg      3
# 11      review  YKOvlBNkF4KpUP9q7x862w  2Zd3Xy8hUVmZkNg7RyNjhg      3
# 12      review  YYy3aQoLvjLhXPkpB32uzA  2Zd3Xy8hUVmZkNg7RyNjhg      3
# 13      review  xY1sPHTA2RGVFlh5tZhs9g  2Zd3Xy8hUVmZkNg7RyNjhg      2
# 14      review  sjCRI-lCh4KLO_RYQdlEeQ  2Zd3Xy8hUVmZkNg7RyNjhg      1
# 15      review  nMHhuYan8e3cONo3PornJA  2Zd3Xy8hUVmZkNg7RyNjhg      5
# 16      review  _WP0nIqmrSFLcY8nV8KUSA  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 17      review  jtzhY-P4H6WSYpv5rWhxtw  2Zd3Xy8hUVmZkNg7RyNjhg      3
# 18      review  Cr2JNnewX53TYd9w6qw6Jw  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 19      review  GDmue1oJaem9ilywDtA4_A  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 20      review  JjLy3f1LyaE9ayRK18XQRg  2Zd3Xy8hUVmZkNg7RyNjhg      4
# 21      review  mxrXVZWc6PWk81gvOVNOUw  fuGfZWfDFf97d6UyuO3d8w      4
# 22      review  E7nk0lC317pGxMX56gvaVQ  fuGfZWfDFf97d6UyuO3d8w      2
# 23      review  66jI6z-JuLasvd692ymycg  fuGfZWfDFf97d6UyuO3d8w      1
# 24      review  IwShjaQLAvqV2msU4bh3ww  fuGfZWfDFf97d6UyuO3d8w      5
# 25      review  mxrXVZWc6PWk81gvOVNOUw  ghvcceMVfgukJMVsi9A1bA      4
# 26      review  UKgSs_SJzW9fu4CwhIV1yA  ghvcceMVfgukJMVsi9A1bA      5
# 27      review  On_3zLdujQdvDbBYUirNWw  ghvcceMVfgukJMVsi9A1bA      3
# 28      review  OE5nAmaSVaopeRS1Cs9Kuw  ghvcceMVfgukJMVsi9A1bA      3
# 29      review  mxrXVZWc6PWk81gvOVNOUw  66aU_4HfubG5wJ3ZPR29og      4
# ...        ...                     ...                     ...    ...
# 547243  review  uJYw4p59AKh8c8h5yWMdOw  uoZfwWjyZ2WwZh5mZDavSg      3
# 547244  review  uJYw4p59AKh8c8h5yWMdOw  bbjBSYN07Om6OCmL-f_fpQ      1
# 547245  review  uJYw4p59AKh8c8h5yWMdOw  3pA7EQTv-hJmdWdQjVmNAg      1
# 547246  review  XG7izXBfvxrZNtjgQWA8tA  3pA7EQTv-hJmdWdQjVmNAg      1
# 547247  review  uJYw4p59AKh8c8h5yWMdOw  PHuODesPB9t_RT9NuGVJWA      5
# 547248  review  uJYw4p59AKh8c8h5yWMdOw  Muqs5VhklzOvEQgEHYbDkw      1
# 547249  review  Nw8lWJRGybAsciao9h-R2Q  Muqs5VhklzOvEQgEHYbDkw      5
# 547250  review  sih8j621A66QoiUFues5qQ  Muqs5VhklzOvEQgEHYbDkw      1
# 547251  review  o3AVHzQR-q8yx3inBelvXA  Muqs5VhklzOvEQgEHYbDkw      5
# 547252  review  u5bGaiZGosBf-L9lYLCg5g  Muqs5VhklzOvEQgEHYbDkw      5
# 547253  review  uJYw4p59AKh8c8h5yWMdOw  Q6jZOJKSvbzcLFebk_NIaQ      3
# 547254  review  uJYw4p59AKh8c8h5yWMdOw  9ylE8m-hEm3lwboPnIb-tA      5
# 547255  review  65_YeaivbdWNk1ZHiAI77w  9ylE8m-hEm3lwboPnIb-tA      1
# 547256  review  sIyHTizqAiGu12XMLX3N3g  9ylE8m-hEm3lwboPnIb-tA      5
# 547257  review  uJYw4p59AKh8c8h5yWMdOw  NQdPrQenFgHdvU_TQR75Mg      1
# 547258  review  uJYw4p59AKh8c8h5yWMdOw  jliMC5OzQigkLPl-lKh65Q      3
# 547259  review  QbmcCE_cLq4WO8ZMKImaLw  jliMC5OzQigkLPl-lKh65Q      5
# 547260  review  uJYw4p59AKh8c8h5yWMdOw  Cm4bdEnwVp-dpYTt5b2OaA      4
# 547261  review  uJYw4p59AKh8c8h5yWMdOw  k8JyU5xQl4L7w1Sp01YugQ      4
# 547262  review  zt1TpTuJ6y9n551sw9TaEg  k8JyU5xQl4L7w1Sp01YugQ      4
# 547263  review  nrtQ1MbahiNDSRn5CyA-Sw  k8JyU5xQl4L7w1Sp01YugQ      4
# 547264  review  aGbjLWzcrnEx2ZmMCFm3EA  k8JyU5xQl4L7w1Sp01YugQ      4
# 547265  review  QhwkFogGQA-Ar176Ul5PUQ  k8JyU5xQl4L7w1Sp01YugQ      3
# 547266  review  VPzETgEJPY0ekHyiCRcqLg  k8JyU5xQl4L7w1Sp01YugQ      4
# 547267  review  uJYw4p59AKh8c8h5yWMdOw  duDHzrsxPCkvScdie495Og      1
# 547268  review  uJYw4p59AKh8c8h5yWMdOw  RbfDvjqqzzqT-ipvWWyPTg      2
# 547269  review  uJYw4p59AKh8c8h5yWMdOw  2K6zSLJy-zxLB7sqONfGvQ      3
# 547270  review  9CLZ-Uwv3nmOlbbGCIhvrQ  2K6zSLJy-zxLB7sqONfGvQ      3
# 547271  review  aGbjLWzcrnEx2ZmMCFm3EA  2K6zSLJy-zxLB7sqONfGvQ      4
# 547272  review  JhfNoSE1DA0tPr3R1MwE8w  2K6zSLJy-zxLB7sqONfGvQ      5
#
#                                                      text        date  \
# 0       Definitely try the duck dish.   I rank it amon...  2011-06-13
# 1       Big Ass Burger was awesome! Great $5 mojitos. ...  2011-06-25
# 2                  Unbelievable sandwiches! Good service.  2011-06-25
# 3       Awesome, awesome, awesome! My mom and sister a...  2011-07-18
# 4       I had the ribs they were great.  The beer sele...  2011-07-19
# 5       Great food, great drink. I had the crab enchil...  2011-07-19
# 6       The only thing keeping this 5 stars is the pri...  2012-10-07
# 7       My wife and I have been to many different Spas...  2010-08-24
# 8       This place in my mind is Postinos meets Bianco...  2011-07-11
# 9       Good lunch place.  Everything I have had is be...  2012-11-17
# 10      When you look at the price you pay you expect ...  2010-08-24
# 11      Very nice restaurant, great food, great servic...  2015-08-24
# 12      The food and service are OK.  I will go back. ...  2014-04-22
# 13      I went here with Friends. All my friends and I...  2011-06-28
# 14      I went here with Friends last Friday.  All my ...  2011-06-27
# 15      This is a unique, awesome place with a cool me...  2011-07-19
# 16      This place is very nice date restaurant.  They...  2012-11-25
# 17      The food was great the service was bad.  If th...  2014-04-22
# 18                                Good burger good value.  2011-07-26
# 19      The food was great.  The service was so-so.  A...  2013-02-14
# 20      The food was very good.  Great flavor not just...  2016-02-11
# 21      I was in Scottsdale on business and this was a...  2011-09-27
# 22      First off to call yourself a bar and not serve...  2011-09-27
# 23      If Toby Keith is affiliated with this place in...  2013-11-13
# 24      This place is a Gem! It's small, dont get me w...  2013-11-28
# 25      Fresh Baked Bread to start!\nGreat Tortilla So...  2011-10-02
# 26      The only thing that comes to my mind is why ar...  2011-10-02
# 27      Service was 4 stars but we're here for the foo...  2011-10-02
# 28      LISTEN CLOSELY FELLOW YELPERS.....\n\nTHIS 3 S...  2011-10-02
# 29      My friends wanted to eat "Southwest cuisine," ...  2011-10-28
# ...                                                   ...         ...
# 547243  I actually really liked this hotel. I got a st...  2016-06-21
# 547244  Awful place, expensive for the things they giv...  2016-06-21
# 547245  Slowest checkin on the Planet. Plan on 1 yo 1 ...  2016-06-21
# 547246  Been in a Sky Priority line for 45 mins. Defin...  2016-06-23
# 547247  It was our first time staying here and we will...  2016-06-21
# 547248  Absolutely the worst place you can stay in Las...  2016-06-23
# 547249  Its really impossible to dislike this place. T...  2016-03-03
# 547250  I love Downtown Las Vegas, I live Downtown. I ...  2016-03-03
# 547251  Now that this place is run by the people from ...  2016-06-23
# 547252  Just great! I am such a fan. I love management...  2016-06-23
# 547253  Stayed here in May since we were seeing JLO at...  2016-06-23
# 547254  My family and I just had another great stay th...  2016-06-27
# 547255  Ate here last night with my family and first i...  2016-06-27
# 547256  Definitely a must for buffet on the strip!! As...  2016-06-27
# 547257  Last weekend, I went to Las Vegas for my bache...  2016-06-28
# 547258  First time in Vegas and we got a great deal. F...  2016-06-30
# 547259  I ordered the Chicken and waffles. Chicken was...  2016-06-30
# 547260  We had a really nice time staying at planet Ho...  2016-07-01
# 547261  I always seem to stay at Planet Hollywood when...  2016-07-03
# 547262  I've been to this buffet a few times now and e...  2016-07-03
# 547263  The Chandelier is one of those fancy schmancy ...  2016-07-03
# 547264  I love BurGR. I make it a point to always eat ...  2016-07-03
# 547265  Although I'm a Cali girl and I'm supposed to b...  2016-07-03
# 547266  The boyfriend and I were heading to Fashion Sh...  2016-07-03
# 547267  My fiance and myself stayed here July 3rd to t...  2016-07-04
# 547268  Non smoking hotel room reeked of smoking.\nCar...  2016-07-06
# 547269  Great location right on the strip but I defini...  2016-07-08
# 547270  If you're staying in Planet Hollywood and look...  2016-07-08
# 547271  I'm not a huge burger person but got dragged i...  2016-07-08
# 547272  The best meal I've had in Vegas so far! Try th...  2016-07-06
#
#         cool_votes  useful_votes  funny_votes
# 0                0             0            0
# 1                1             0            0
# 2                0             0            0
# 3                1             1            0
# 4                1             0            1
# 5                0             0            0
# 6                0             2            0
# 7                0             0            0
# 8                1             1            0
# 9                0             0            0
# 10               0             0            0
# 11               0             0            0
# 12               0             0            0
# 13               1             2            0
# 14               0             5            1
# 15               0             0            0
# 16               1             1            1
# 17               0             1            0
# 18               0             1            0
# 19               0             0            0
# 20               0             0            0
# 21               0             0            0
# 22               0             2            0
# 23               1            10            2
# 24               0             0            0
# 25               0             1            0
# 26               0             1            0
# 27               0             0            0
# 28               0             0            0
# 29               0             0            0
# ...            ...           ...          ...
# 547243           1             1            2
# 547244           0             0            0
# 547245           0             0            0
# 547246           0             0            0
# 547247           0             0            0
# 547248           0             0            1
# 547249           0             0            0
# 547250           0             0            0
# 547251           0             0            0
# 547252           0             0            0
# 547253           0             1            0
# 547254           0             0            0
# 547255           0             0            0
# 547256           0             0            0
# 547257           0             0            0
# 547258           0             0            0
# 547259           0             0            0
# 547260           0             0            0
# 547261           0             0            0
# 547262           0             1            0
# 547263           0             0            0
# 547264           0             1            0
# 547265           1             0            0
# 547266           1             3            1
# 547267           0             0            0
# 547268           0             1            0
# 547269           0             1            1
# 547270           0             1            0
# 547271           1             0            0
# 547272           0             0            0
#
# [547273 rows x 9 columns]

# %% [markdown]
# #### 1. What was the highest number and mean of reviews for any one business_id?

# %%
yelp_businesses = df.groupby('business_id').size()

print('[1] BUSINESS MEAN :: ', yelp_businesses.mean())
# Out:
# [1] BUSINESS MEAN ::  12.63413902163123

# %% [markdown]
# #### 2. What was the average number of reviews for a business_id?

# %%
yelp_businesses = df.groupby('business_id').size()

print('[2] BUSINESS MAX :: ', yelp_businesses.max())
# Out:
# [2] BUSINESS MAX ::  4128

# %% [markdown]
# #### 3. Generate the following values, which are as per reviewer:

# %% [markdown]
# ##### 3A - What is the average number of reviews per reviewer?

# %%
yelp_reviewer = df.groupby('user_id').size()

print('[3A] REVIEWER MEAN :: ', yelp_reviewer.mean())
# Out:
# [3A] REVIEWER MEAN ::  3.188511934933203

# %% [markdown]
# ##### 3B, 3C, 3D - What is the average number of [cool, funny, useful] votes per reviewer?

# %%
yelp_reviewer = df.groupby('user_id').sum()

print('[3B] REVIEWER <cool_votes> MEAN :: ', yelp_reviewer['cool_votes'].mean())
print('[3C] REVIEWER <funny_votes> MEAN :: ', yelp_reviewer['funny_votes'].mean())
print('[3D] REVIEWER <useful_votes> MEAN :: ', yelp_reviewer['useful_votes'].mean())
# Out:
# [3B] REVIEWER <cool_votes> MEAN ::  1.2417282785380945
# [3C] REVIEWER <funny_votes> MEAN ::  1.10126486404605
# [3D] REVIEWER <useful_votes> MEAN ::  2.484476138872867

# %% [markdown]
# ##### 3E - What is the average of the log of the number of reviews per reviewer?

# %%
yelp_reviewer = df.groupby('user_id').size().apply(np.log)
yelp_reviewer = yelp_reviewer.replace('-Inf', 'NaN')

print('[3E] REVIEWER log MEAN :: ', yelp_reviewer.mean())
# Out:
# [3E] REVIEWER log MEAN ::  0.7681766036714884

# %% [markdown]
# ##### 3F, 3G, 3H - What is the average of the log of the number of [cool, funny, useful ] votes per reviewer?

# %%
yelp_reviewer = df.groupby('user_id').sum().replace(0, np.NaN).apply(np.log)

print('[3F] REVIEWER <cool_votes> log MEAN :: ', yelp_reviewer['cool_votes'].mean())
print('[3G] REVIEWER <funny_votes> log MEAN :: ', yelp_reviewer['funny_votes'].mean())
print('[3H] REVIEWER <useful_votes> log MEAN :: ', yelp_reviewer['useful_votes'].mean())
# Out:
# [3F] REVIEWER <cool_votes> log MEAN ::  0.6653356886590631
# [3G] REVIEWER <funny_votes> log MEAN ::  0.6608793976228501
# [3H] REVIEWER <useful_votes> log MEAN ::  0.9106025900077512

# %% [markdown]
# ##### 3I, 3J, 3K Find the average of the percentage of total [cool, funny, useful] votes out of total votes for each reviewer.

# %%
yelp_reviewer_percentage = df.groupby('user_id').sum()
yelp_reviewer_percentage['total_votes'] = yelp_reviewer_percentage[['cool_votes', 'funny_votes', 'useful_votes']].sum(axis=1)

yelp_reviewer_percentage = yelp_reviewer_percentage[['cool_votes', 'funny_votes', 'useful_votes']].divide(yelp_reviewer_percentage['total_votes'], axis=0)


print('[3I] REVIEWER <cool_votes> PERCENTAGE :: ', yelp_reviewer_percentage['cool_votes'].mean())
print('[3J] REVIEWER <funny_votes> PERCENTAGE :: ', yelp_reviewer_percentage['funny_votes'].mean())
print('[3K] REVIEWER <useful_votes> PERCENTAGE :: ', yelp_reviewer_percentage['useful_votes'].mean())
# Out:
# [3I] REVIEWER <cool_votes> PERCENTAGE ::  0.1927040524186044
# [3J] REVIEWER <funny_votes> PERCENTAGE ::  0.18256423845801606
# [3K] REVIEWER <useful_votes> PERCENTAGE ::  0.6247317091233795

# %% [markdown]
# ##### 3L - Average review text length (in non-space characters)

# %%
yelp_reviewer_text = df['text'].str.replace(' ', '')
yelp_reviewer_text = yelp_reviewer_text.str.len()

print('[3L] TEXT LENGTH MEAN :: ', yelp_reviewer_text.mean())
# Out:
# [3L] TEXT LENGTH MEAN ::  499.02532556877463

# %% [markdown]
# ##### 3M - Year in which the reviewer wrote the most reviews.
#
# *Once you have this for each reviewer, subtract the minimum possible year (2005) from each so that your final feature values are 0, 1, 2 etc.*

# %%
yelp_reviewer_year = df.drop(columns=['type', 'business_id', 'stars', 'text', 'cool_votes', 'useful_votes', 'funny_votes'])
yelp_reviewer_year['year'] = yelp_reviewer_year['date'].apply(lambda d: int(d.split('-')[0]))
yelp_reviewer_year['count'] = 1

# Solution using manual encoding: There should be a better way to do this, though.
# ----
yelp_reviewer_year = yelp_reviewer_year.groupby(['user_id', 'year'], as_index=False).count()
yelp_reviewer_year['max'] = yelp_reviewer_year.groupby(['user_id'])['count'].transform(max)
yelp_reviewer_year['encoded'] = yelp_reviewer_year['max'].multiply(10000).add(yelp_reviewer_year['year'])
yelp_reviewer_year = yelp_reviewer_year.drop(columns=['year', 'date', 'count', 'max'])
yelp_reviewer_year = yelp_reviewer_year.groupby(['user_id']).max()
yelp_reviewer_year['posts'] = yelp_reviewer_year['encoded'].apply(lambda x: int(x / 10000))
yelp_reviewer_year['year'] = yelp_reviewer_year['encoded'].apply(lambda x: x % 10000)
yelp_reviewer_year['year_encoded'] = yelp_reviewer_year['year'].subtract(2005)
yelp_reviewer_year = yelp_reviewer_year.drop(columns=['encoded'])
# ----

# yelp_reviewer_year.loc['mv7shusL4Xb6TylVYBv4CA'] 
# yelp_reviewer_year.loc['zzvflqB4xAcKFbIbS6HSOw'] 

yelp_reviewer_year
# Out:
#                         posts  year  year_encoded
# user_id
# --1Y03CEKR3WDbBjYnsW7A      1  2011             6
# --2QZsyXGz1OhiD4-0FQLQ      3  2014             9
# --82_AVgRBsLw6Dhy8sEnA      1  2008             3
# --8A9o_NeGyt_3kzlXtSdg      2  2016            11
# --8WbseBk1NjfPiZWjQ-XQ      4  2016            11
# --9HuvEtLhp21SeIEEltnA      3  2014             9
# --AqBuo717RyacADExYbSA      3  2016            11
# --BGW_TY55SH-9OiHmtitg      1  2014             9
# --CUu8WmGg1b9tsbSFzfoQ      2  2015            10
# --CYRho74XMU1UC_b8WSDQ      1  2015            10
# --D6B8SF9EAIaS4O7wLVJw      2  2011             6
# --E8HPRm1TvCpBFrDRfq2A      4  2013             8
# --Gjrja8RffTz9nKHXsXpA      3  2014             9
# --JC6ri9lh1-tazGOFA3yg      2  2012             7
# --KQYYmWTDF8ahsIryg_0g      1  2012             7
# --KcMwfiUXc6Gd8kbjRncQ      1  2011             6
# --RM-_N1-5AiFSzdU5Gn1Q      8  2010             5
# --SvPSowPM7hcFYOPmHxbw      1  2015            10
# --TBq4e5lF6-KhfVk6aALQ      3  2015            10
# --Yzpb7MUxskzAXktJtlEQ      1  2010             5
# --aRast0uc07BiKdGxHbeg      1  2013             8
# --bicnC0I5uQJWH_hbnnjA      1  2015            10
# --bmQJBvKmn55eEtMJepHg      2  2015            10
# --c_BikxInU2t8uoo3b9iA      1  2015            10
# --d573uVjjBKmIWyRyuMgQ      4  2016            11
# --eSvyotKiOHQlAf8rxlhg      1  2011             6
# --hWC2FYuvaItr5-_Hp8Mg      1  2013             8
# --ijvARuRJhZrBdS9_jF2A      2  2014             9
# --klqiKlQyPd_5f1apyB4Q      1  2012             7
# --mUxQG05DwbTd_Y8uCAFw      3  2016            11
# ...                       ...   ...           ...
# zzGvW_YzIY1kL8tP--v-5A      1  2012             7
# zzJYSV5tgvgKuz7RxovBCw      3  2016            11
# zzKwC0l7DvEZ5rMsIt65UA      2  2013             8
# zzNAA2WL2rdSB40oS4U2ZQ      1  2014             9
# zzRNf7h36Iu641FqHDdCww      1  2014             9
# zzTAZPUSMflAB9oDxI2IxQ      1  2016            11
# zzUDJnQIvcrOLd-FR1g6ow      4  2016            11
# zzV2ND3V2gypodwjCbafuQ      1  2012             7
# zzWC28uFmgy2ecENkiHV-g      1  2015            10
# zzWUzYAj8SXwohidVLax9Q      2  2008             3
# zzXoE0YP5IPUmvF1vv4dfg      2  2016            11
# zzZlKcKK3It4IQYVqfU9YA      3  2015            10
# zzaZ12qPD__M0-6TEf-hyQ      1  2013             8
# zzbpxwe3zjziyQOqeyHV8Q      1  2016            11
# zzcXV1uRJ8gNrwY652fBpA      1  2016            11
# zzeINaobCDQgC6DvOsuzoA      1  2010             5
# zzgJ9L18TJUVN72Iio0B_w      8  2014             9
# zzgZQ82lydXrHM-tI-RsWw      3  2015            10
# zzjbYl789JCxRoccM1TpUQ      6  2013             8
# zzkdO7PCnWI7tWoEV7JF0g      1  2015            10
# zzlEOrvF8EkkX4fxCwPZdw      2  2011             6
# zznPTkBKMznV8RdqvDX5Jw      1  2015            10
# zzpT-Mfyh4jEjdqDerSVnQ      3  2015            10
# zzrNDzW1GxgaWTBD2yeaaQ      1  2015            10
# zzu0dZXo10IxEJduMVHgTg      2  2016            11
# zzv762b871Wp3SVxsFQqHw      1  2015            10
# zzvflqB4xAcKFbIbS6HSOw     10  2014             9
# zzwu0nG0MCUP43zNSr5k-A      1  2015            10
# zzx-JA0qEz5eTO3GMv99NA      1  2015            10
# zzyeArRv6I5HpEJlOCOPAQ      1  2016            11
#
# [171639 rows x 3 columns]

# %% [markdown]
# ##### 4. Come up with a new feature.

# %% [markdown]
# **Idea:** Average rating for each reviewer

# %%
yelp_reviewer_average_stars = df.groupby('user_id')['stars'].mean()

file_name = 'out.csv'
yelp_reviewer_average_stars.to_csv(file_name, header =  ['avg_stars'], encoding='utf-8')

# Check new file
new_df = pd.read_csv(file_name)
new_df
# Out:
#                        user_id  avg_stars
# 0       --1Y03CEKR3WDbBjYnsW7A   5.000000
# 1       --2QZsyXGz1OhiD4-0FQLQ   4.666667
# 2       --82_AVgRBsLw6Dhy8sEnA   4.000000
# 3       --8A9o_NeGyt_3kzlXtSdg   3.666667
# 4       --8WbseBk1NjfPiZWjQ-XQ   2.750000
# 5       --9HuvEtLhp21SeIEEltnA   3.666667
# 6       --AqBuo717RyacADExYbSA   3.375000
# 7       --BGW_TY55SH-9OiHmtitg   1.000000
# 8       --CUu8WmGg1b9tsbSFzfoQ   4.000000
# 9       --CYRho74XMU1UC_b8WSDQ   3.500000
# 10      --D6B8SF9EAIaS4O7wLVJw   3.666667
# 11      --E8HPRm1TvCpBFrDRfq2A   2.250000
# 12      --Gjrja8RffTz9nKHXsXpA   3.000000
# 13      --JC6ri9lh1-tazGOFA3yg   4.000000
# 14      --KQYYmWTDF8ahsIryg_0g   5.000000
# 15      --KcMwfiUXc6Gd8kbjRncQ   4.000000
# 16      --RM-_N1-5AiFSzdU5Gn1Q   4.083333
# 17      --SvPSowPM7hcFYOPmHxbw   5.000000
# 18      --TBq4e5lF6-KhfVk6aALQ   3.666667
# 19      --Yzpb7MUxskzAXktJtlEQ   3.000000
# 20      --aRast0uc07BiKdGxHbeg   4.000000
# 21      --bicnC0I5uQJWH_hbnnjA   3.000000
# 22      --bmQJBvKmn55eEtMJepHg   4.666667
# 23      --c_BikxInU2t8uoo3b9iA   5.000000
# 24      --d573uVjjBKmIWyRyuMgQ   4.000000
# 25      --eSvyotKiOHQlAf8rxlhg   5.000000
# 26      --hWC2FYuvaItr5-_Hp8Mg   5.000000
# 27      --ijvARuRJhZrBdS9_jF2A   1.000000
# 28      --klqiKlQyPd_5f1apyB4Q   5.000000
# 29      --mUxQG05DwbTd_Y8uCAFw   4.333333
# ...                        ...        ...
# 171609  zzGvW_YzIY1kL8tP--v-5A   5.000000
# 171610  zzJYSV5tgvgKuz7RxovBCw   4.142857
# 171611  zzKwC0l7DvEZ5rMsIt65UA   3.000000
# 171612  zzNAA2WL2rdSB40oS4U2ZQ   5.000000
# 171613  zzRNf7h36Iu641FqHDdCww   1.000000
# 171614  zzTAZPUSMflAB9oDxI2IxQ   3.500000
# 171615  zzUDJnQIvcrOLd-FR1g6ow   3.666667
# 171616  zzV2ND3V2gypodwjCbafuQ   3.000000
# 171617  zzWC28uFmgy2ecENkiHV-g   4.000000
# 171618  zzWUzYAj8SXwohidVLax9Q   4.000000
# 171619  zzXoE0YP5IPUmvF1vv4dfg   5.000000
# 171620  zzZlKcKK3It4IQYVqfU9YA   4.000000
# 171621  zzaZ12qPD__M0-6TEf-hyQ   5.000000
# 171622  zzbpxwe3zjziyQOqeyHV8Q   5.000000
# 171623  zzcXV1uRJ8gNrwY652fBpA   5.000000
# 171624  zzeINaobCDQgC6DvOsuzoA   5.000000
# 171625  zzgJ9L18TJUVN72Iio0B_w   2.875000
# 171626  zzgZQ82lydXrHM-tI-RsWw   3.625000
# 171627  zzjbYl789JCxRoccM1TpUQ   2.857143
# 171628  zzkdO7PCnWI7tWoEV7JF0g   3.000000
# 171629  zzlEOrvF8EkkX4fxCwPZdw   5.000000
# 171630  zznPTkBKMznV8RdqvDX5Jw   1.000000
# 171631  zzpT-Mfyh4jEjdqDerSVnQ   4.333333
# 171632  zzrNDzW1GxgaWTBD2yeaaQ   1.000000
# 171633  zzu0dZXo10IxEJduMVHgTg   4.000000
# 171634  zzv762b871Wp3SVxsFQqHw   4.000000
# 171635  zzvflqB4xAcKFbIbS6HSOw   4.250000
# 171636  zzwu0nG0MCUP43zNSr5k-A   5.000000
# 171637  zzx-JA0qEz5eTO3GMv99NA   1.000000
# 171638  zzyeArRv6I5HpEJlOCOPAQ   2.333333
#
# [171639 rows x 2 columns]
